# %% [markdown]
# ## Importações

# %%
from funcoes.funcoes import *

pd.set_option('display.max_rows', 200)

# %%
X_train = pd.read_csv('dados/X_train.csv')
X_test  = pd.read_csv('dados/X_test.csv')
y_train = pd.read_csv('dados/y_train.csv')
y_test  = pd.read_csv('dados/y_test.csv')

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (326399, 104)
# (326399, 1)
# (139886, 104)
# (139886, 1)

# %% [markdown]
# ---
#
# ## 1. Criando um scorecard

# %%
reg = LogisticRegressionPValues()

reg.fit(X_train, y_train)

# %%
nomes_features = X_train.columns

# %%
tabela_sumario = pd.DataFrame(columns = ['nome_feature'], data = nomes_features)
tabela_sumario['coeficiente'] = np.transpose(reg.coef_)
tabela_sumario.index = tabela_sumario.index + 1
tabela_sumario.loc[0] = ['intercept', reg.intercept_[0]]
tabela_sumario = tabela_sumario.sort_index()

p_values = reg.p_values
p_values = np.append(np.nan,np.array(p_values))
tabela_sumario['p_valor'] = p_values
tabela_sumario
# Out:
#                             nome_feature  coeficiente        p_valor
# 0                              intercept    -1.371397            NaN
# 1                                grade:A     1.120239   1.705517e-30
# 2                                grade:B     0.891872   1.198637e-42
# 3                                grade:C     0.706093   1.383027e-31
# 4                                grade:D     0.529578   2.517464e-20
# 5                                grade:E     0.344007   1.869595e-11
# 6                                grade:F     0.181411   6.870495e-04
# 7                     home_ownership:OWN     0.080838   1.659498e-04
# 8                home_ownership:MORTGAGE     0.118092   3.618968e-18
# 9                       addr_state:NM_VA     0.038921   2.552631e-01
# 10                         addr_state:NY     0.061426   1.807077e-02
# 11          addr_state:OK_TN_MO_LA_MD_NC     0.055567   2.495962e-02
# 12                         addr_state:CA     0.066356   3.495677e-03
# 13                addr_state:UT_KY_AZ_NJ     0.075903   4.320970e-03
# 14             addr_state:AR_MI_PA_OH_MN     0.140124   6.295668e-09
# 15             addr_state:RI_MA_DE_SD_IN     0.091620   4.048894e-03
# 16                   addr_state:GA_WA_OR     0.209991   2.350712e-13
# 17                      addr_state:WI_MT     0.263169   2.998592e-07
# 18                         addr_state:TX     0.213835   1.349446e-14
# 19                      addr_state:IL_CT     0.275203   1.639024e-18
# 20          addr_state:KS_SC_CO_VT_AK_MS     0.302989   3.206527e-20
# 21          addr_state:WV_NH_WY_DC_ME_ID     0.448291   5.728476e-16
# 22      verification_status:Not Verified     0.108887   4.650683e-12
# 23   verification_status:Source Verified     0.005561   6.987679e-01
# 24                   purpose:credit_card     0.302932   2.090231e-23
# 25            purpose:debt_consolidation     0.189525   1.130595e-11
# 26            purpose:oth__med__vacation     0.192464   7.409649e-09
# 27   purpose:major_purch__car__home_impr     0.247194   1.573550e-13
# 28                 initial_list_status:w     0.069243   7.285469e-07
# 29                               term:36     0.085792   1.492822e-08
# 30                          emp_length:1     0.112939   5.022189e-05
# 31                        emp_length:2-4     0.126190   4.443237e-10
# 32                        emp_length:5-6     0.076540   8.095626e-04
# 33                        emp_length:7-9     0.058436   8.725434e-03
# 34                         emp_length:10     0.129819   5.004927e-11
# 35                mths_since_issue_d:<38     1.040987  4.818019e-142
# 36              mths_since_issue_d:38-39     0.874636  5.561227e-123
# 37              mths_since_issue_d:40-41     0.776557  9.703474e-102
# 38              mths_since_issue_d:42-48     0.556012   3.875045e-67
# 39              mths_since_issue_d:49-52     0.419556   1.706727e-34
# 40              mths_since_issue_d:53-64     0.184479   1.091953e-08
# 41              mths_since_issue_d:65-84    -0.071832   2.221073e-02
# 42                       int_rate:<9.548     0.909501   1.862597e-28
# 43                 int_rate:9.548-12.025     0.577437   2.684331e-33
# 44                 int_rate:12.025-15.74     0.305270   1.004183e-14
# 45                 int_rate:15.74-20.281     0.096453   1.894529e-03
# 46   mths_since_earliest_cr_line:141-164     0.076505   4.289903e-03
# 47   mths_since_earliest_cr_line:165-247     0.047317   2.945645e-02
# 48   mths_since_earliest_cr_line:248-270     0.074403   8.673981e-03
# 49   mths_since_earliest_cr_line:271-352     0.136221   9.650868e-08
# 50      mths_since_earliest_cr_line:>352     0.133434   3.864068e-06
# 51                         delinq_2yrs:0     0.064171   2.913999e-01
# 52                       delinq_2yrs:1-3     0.008231   8.854481e-01
# 53                      inq_last_6mths:0     0.729960   3.825313e-09
# 54                    inq_last_6mths:1-2     0.587147   2.077073e-06
# 55                    inq_last_6mths:3-6     0.386399   1.872395e-03
# 56                          open_acc:1-3    -0.064582   7.185561e-01
# 57                         open_acc:4-12    -0.126531   4.704781e-01
# 58                        open_acc:13-17    -0.137366   4.342373e-01
# 59                        open_acc:18-22    -0.159259   3.673023e-01
# 60                        open_acc:23-25    -0.136569   4.527126e-01
# 61                        open_acc:26-30    -0.150296   4.212804e-01
# 62                         open_acc:>=31    -0.186017   3.564643e-01
# 63                           pub_rec:3-4     0.033668   7.305199e-01
# 64                           pub_rec:>=5     0.040164   8.330900e-01
# 65                       total_acc:28-51    -0.018672   2.191139e-01
# 66                        total_acc:>=52    -0.034813   4.048570e-01
# 67                    acc_now_delinq:>=1     0.168730   1.327620e-01
# 68               total_rev_hi_lim:5K-10K     0.013172   6.176985e-01
# 69              total_rev_hi_lim:10K-20K    -0.000652   9.796862e-01
# 70              total_rev_hi_lim:20K-30K     0.005408   8.477255e-01
# 71              total_rev_hi_lim:30K-40K    -0.011052   7.258825e-01
# 72              total_rev_hi_lim:40K-55K     0.041321   2.307736e-01
# 73              total_rev_hi_lim:55K-95K     0.063422   9.999395e-02
# 74                 total_rev_hi_lim:>95K     0.202200   7.614600e-04
# 75                    annual_inc:20K-30K    -0.063282   1.685759e-01
# 76                    annual_inc:30K-40K    -0.007194   8.712086e-01
# 77                    annual_inc:40K-50K     0.107380   1.572607e-02
# 78                    annual_inc:50K-60K     0.151162   7.886802e-04
# 79                    annual_inc:60K-70K     0.237277   2.708393e-07
# 80                    annual_inc:70K-80K     0.298050   2.431056e-10
# 81                    annual_inc:80K-90K     0.384270   4.726272e-15
# 82                   annual_inc:90K-100K     0.398392   3.878425e-15
# 83                  annual_inc:100K-120K     0.454093   1.786500e-19
# 84                  annual_inc:120K-140K     0.545912   8.986038e-22
# 85                      annual_inc:>140K     0.469262   6.838232e-19
# 86                             dti:<=1.4     0.247248   1.002660e-02
# 87                           dti:1.4-3.5     0.349212   1.678895e-05
# 88                           dti:3.5-7.7     0.309396   1.191862e-05
# 89                          dti:7.7-10.5     0.261016   1.964027e-04
# 90                         dti:10.5-16.1     0.186179   6.195766e-03
# 91                         dti:16.1-20.3     0.097779   1.503448e-01
# 92                         dti:20.3-21.7     0.093219   1.865510e-01
# 93                         dti:21.7-22.4     0.040482   5.872295e-01
# 94                           dti:22.4-35    -0.001991   9.763588e-01
# 95        mths_since_last_delinq:Missing     0.043164   4.867386e-01
# 96           mths_since_last_delinq:4-30     0.106192   6.470523e-02
# 97          mths_since_last_delinq:31-56     0.110025   8.165944e-02
# 98           mths_since_last_delinq:>=57     0.069058   2.835101e-01
# 99        mths_since_last_record:Missing     0.371095   5.331083e-05
# 100          mths_since_last_record:3-20     0.385860   3.406373e-03
# 101         mths_since_last_record:21-31     0.451669   3.166182e-04
# 102         mths_since_last_record:32-80     0.616042   1.622830e-10
# 103         mths_since_last_record:81-86     0.257033   2.331781e-02
# 104           mths_since_last_record:>86     0.318918   7.666102e-04

# %% [markdown]
# Criação de um score calculado com base nos coeficientes, em que coeficientes maiores vão corresponder consequentemente a melhores mutuários.

# %%
# criando um dataframe

df_ref_categorias = pd.DataFrame()


# concatenando o datafram com a tabela sumario

df_scorecard = pd.concat([tabela_sumario, df_ref_categorias])
df_scorecard = df_scorecard.reset_index()

df_scorecard['nome_original_feature'] = df_scorecard['nome_feature'].str.split(':').str[0]
df_scorecard
# Out:
#      index                         nome_feature  coeficiente        p_valor  \
# 0        0                            intercept    -1.371397            NaN
# 1        1                              grade:A     1.120239   1.705517e-30
# 2        2                              grade:B     0.891872   1.198637e-42
# 3        3                              grade:C     0.706093   1.383027e-31
# 4        4                              grade:D     0.529578   2.517464e-20
# 5        5                              grade:E     0.344007   1.869595e-11
# 6        6                              grade:F     0.181411   6.870495e-04
# 7        7                   home_ownership:OWN     0.080838   1.659498e-04
# 8        8              home_ownership:MORTGAGE     0.118092   3.618968e-18
# 9        9                     addr_state:NM_VA     0.038921   2.552631e-01
# 10      10                        addr_state:NY     0.061426   1.807077e-02
# 11      11         addr_state:OK_TN_MO_LA_MD_NC     0.055567   2.495962e-02
# 12      12                        addr_state:CA     0.066356   3.495677e-03
# 13      13               addr_state:UT_KY_AZ_NJ     0.075903   4.320970e-03
# 14      14            addr_state:AR_MI_PA_OH_MN     0.140124   6.295668e-09
# 15      15            addr_state:RI_MA_DE_SD_IN     0.091620   4.048894e-03
# 16      16                  addr_state:GA_WA_OR     0.209991   2.350712e-13
# 17      17                     addr_state:WI_MT     0.263169   2.998592e-07
# 18      18                        addr_state:TX     0.213835   1.349446e-14
# 19      19                     addr_state:IL_CT     0.275203   1.639024e-18
# 20      20         addr_state:KS_SC_CO_VT_AK_MS     0.302989   3.206527e-20
# 21      21         addr_state:WV_NH_WY_DC_ME_ID     0.448291   5.728476e-16
# 22      22     verification_status:Not Verified     0.108887   4.650683e-12
# 23      23  verification_status:Source Verified     0.005561   6.987679e-01
# 24      24                  purpose:credit_card     0.302932   2.090231e-23
# 25      25           purpose:debt_consolidation     0.189525   1.130595e-11
# 26      26           purpose:oth__med__vacation     0.192464   7.409649e-09
# 27      27  purpose:major_purch__car__home_impr     0.247194   1.573550e-13
# 28      28                initial_list_status:w     0.069243   7.285469e-07
# 29      29                              term:36     0.085792   1.492822e-08
# 30      30                         emp_length:1     0.112939   5.022189e-05
# 31      31                       emp_length:2-4     0.126190   4.443237e-10
# 32      32                       emp_length:5-6     0.076540   8.095626e-04
# 33      33                       emp_length:7-9     0.058436   8.725434e-03
# 34      34                        emp_length:10     0.129819   5.004927e-11
# 35      35               mths_since_issue_d:<38     1.040987  4.818019e-142
# 36      36             mths_since_issue_d:38-39     0.874636  5.561227e-123
# 37      37             mths_since_issue_d:40-41     0.776557  9.703474e-102
# 38      38             mths_since_issue_d:42-48     0.556012   3.875045e-67
# 39      39             mths_since_issue_d:49-52     0.419556   1.706727e-34
# 40      40             mths_since_issue_d:53-64     0.184479   1.091953e-08
# 41      41             mths_since_issue_d:65-84    -0.071832   2.221073e-02
# 42      42                      int_rate:<9.548     0.909501   1.862597e-28
# 43      43                int_rate:9.548-12.025     0.577437   2.684331e-33
# 44      44                int_rate:12.025-15.74     0.305270   1.004183e-14
# 45      45                int_rate:15.74-20.281     0.096453   1.894529e-03
# 46      46  mths_since_earliest_cr_line:141-164     0.076505   4.289903e-03
# 47      47  mths_since_earliest_cr_line:165-247     0.047317   2.945645e-02
# 48      48  mths_since_earliest_cr_line:248-270     0.074403   8.673981e-03
# 49      49  mths_since_earliest_cr_line:271-352     0.136221   9.650868e-08
# 50      50     mths_since_earliest_cr_line:>352     0.133434   3.864068e-06
# 51      51                        delinq_2yrs:0     0.064171   2.913999e-01
# 52      52                      delinq_2yrs:1-3     0.008231   8.854481e-01
# 53      53                     inq_last_6mths:0     0.729960   3.825313e-09
# 54      54                   inq_last_6mths:1-2     0.587147   2.077073e-06
# 55      55                   inq_last_6mths:3-6     0.386399   1.872395e-03
# 56      56                         open_acc:1-3    -0.064582   7.185561e-01
# 57      57                        open_acc:4-12    -0.126531   4.704781e-01
# 58      58                       open_acc:13-17    -0.137366   4.342373e-01
# 59      59                       open_acc:18-22    -0.159259   3.673023e-01
# 60      60                       open_acc:23-25    -0.136569   4.527126e-01
# 61      61                       open_acc:26-30    -0.150296   4.212804e-01
# 62      62                        open_acc:>=31    -0.186017   3.564643e-01
# 63      63                          pub_rec:3-4     0.033668   7.305199e-01
# 64      64                          pub_rec:>=5     0.040164   8.330900e-01
# 65      65                      total_acc:28-51    -0.018672   2.191139e-01
# 66      66                       total_acc:>=52    -0.034813   4.048570e-01
# 67      67                   acc_now_delinq:>=1     0.168730   1.327620e-01
# 68      68              total_rev_hi_lim:5K-10K     0.013172   6.176985e-01
# 69      69             total_rev_hi_lim:10K-20K    -0.000652   9.796862e-01
# 70      70             total_rev_hi_lim:20K-30K     0.005408   8.477255e-01
# 71      71             total_rev_hi_lim:30K-40K    -0.011052   7.258825e-01
# 72      72             total_rev_hi_lim:40K-55K     0.041321   2.307736e-01
# 73      73             total_rev_hi_lim:55K-95K     0.063422   9.999395e-02
# 74      74                total_rev_hi_lim:>95K     0.202200   7.614600e-04
# 75      75                   annual_inc:20K-30K    -0.063282   1.685759e-01
# 76      76                   annual_inc:30K-40K    -0.007194   8.712086e-01
# 77      77                   annual_inc:40K-50K     0.107380   1.572607e-02
# 78      78                   annual_inc:50K-60K     0.151162   7.886802e-04
# 79      79                   annual_inc:60K-70K     0.237277   2.708393e-07
# 80      80                   annual_inc:70K-80K     0.298050   2.431056e-10
# 81      81                   annual_inc:80K-90K     0.384270   4.726272e-15
# 82      82                  annual_inc:90K-100K     0.398392   3.878425e-15
# 83      83                 annual_inc:100K-120K     0.454093   1.786500e-19
# 84      84                 annual_inc:120K-140K     0.545912   8.986038e-22
# 85      85                     annual_inc:>140K     0.469262   6.838232e-19
# 86      86                            dti:<=1.4     0.247248   1.002660e-02
# 87      87                          dti:1.4-3.5     0.349212   1.678895e-05
# 88      88                          dti:3.5-7.7     0.309396   1.191862e-05
# 89      89                         dti:7.7-10.5     0.261016   1.964027e-04
# 90      90                        dti:10.5-16.1     0.186179   6.195766e-03
# 91      91                        dti:16.1-20.3     0.097779   1.503448e-01
# 92      92                        dti:20.3-21.7     0.093219   1.865510e-01
# 93      93                        dti:21.7-22.4     0.040482   5.872295e-01
# 94      94                          dti:22.4-35    -0.001991   9.763588e-01
# 95      95       mths_since_last_delinq:Missing     0.043164   4.867386e-01
# 96      96          mths_since_last_delinq:4-30     0.106192   6.470523e-02
# 97      97         mths_since_last_delinq:31-56     0.110025   8.165944e-02
# 98      98          mths_since_last_delinq:>=57     0.069058   2.835101e-01
# 99      99       mths_since_last_record:Missing     0.371095   5.331083e-05
# 100    100          mths_since_last_record:3-20     0.385860   3.406373e-03
# 101    101         mths_since_last_record:21-31     0.451669   3.166182e-04
# 102    102         mths_since_last_record:32-80     0.616042   1.622830e-10
# 103    103         mths_since_last_record:81-86     0.257033   2.331781e-02
# 104    104           mths_since_last_record:>86     0.318918   7.666102e-04
#
#            nome_original_feature
# 0                      intercept
# 1                          grade
# 2                          grade
# 3                          grade
# 4                          grade
# 5                          grade
# 6                          grade
# 7                 home_ownership
# 8                 home_ownership
# 9                     addr_state
# 10                    addr_state
# 11                    addr_state
# 12                    addr_state
# 13                    addr_state
# 14                    addr_state
# 15                    addr_state
# 16                    addr_state
# 17                    addr_state
# 18                    addr_state
# 19                    addr_state
# 20                    addr_state
# 21                    addr_state
# 22           verification_status
# 23           verification_status
# 24                       purpose
# 25                       purpose
# 26                       purpose
# 27                       purpose
# 28           initial_list_status
# 29                          term
# 30                    emp_length
# 31                    emp_length
# 32                    emp_length
# 33                    emp_length
# 34                    emp_length
# 35            mths_since_issue_d
# 36            mths_since_issue_d
# 37            mths_since_issue_d
# 38            mths_since_issue_d
# 39            mths_since_issue_d
# 40            mths_since_issue_d
# 41            mths_since_issue_d
# 42                      int_rate
# 43                      int_rate
# 44                      int_rate
# 45                      int_rate
# 46   mths_since_earliest_cr_line
# 47   mths_since_earliest_cr_line
# 48   mths_since_earliest_cr_line
# 49   mths_since_earliest_cr_line
# 50   mths_since_earliest_cr_line
# 51                   delinq_2yrs
# 52                   delinq_2yrs
# 53                inq_last_6mths
# 54                inq_last_6mths
# 55                inq_last_6mths
# 56                      open_acc
# 57                      open_acc
# 58                      open_acc
# 59                      open_acc
# 60                      open_acc
# 61                      open_acc
# 62                      open_acc
# 63                       pub_rec
# 64                       pub_rec
# 65                     total_acc
# 66                     total_acc
# 67                acc_now_delinq
# 68              total_rev_hi_lim
# 69              total_rev_hi_lim
# 70              total_rev_hi_lim
# 71              total_rev_hi_lim
# 72              total_rev_hi_lim
# 73              total_rev_hi_lim
# 74              total_rev_hi_lim
# 75                    annual_inc
# 76                    annual_inc
# 77                    annual_inc
# 78                    annual_inc
# 79                    annual_inc
# 80                    annual_inc
# 81                    annual_inc
# 82                    annual_inc
# 83                    annual_inc
# 84                    annual_inc
# 85                    annual_inc
# 86                           dti
# 87                           dti
# 88                           dti
# 89                           dti
# 90                           dti
# 91                           dti
# 92                           dti
# 93                           dti
# 94                           dti
# 95        mths_since_last_delinq
# 96        mths_since_last_delinq
# 97        mths_since_last_delinq
# 98        mths_since_last_delinq
# 99        mths_since_last_record
# 100       mths_since_last_record
# 101       mths_since_last_record
# 102       mths_since_last_record
# 103       mths_since_last_record
# 104       mths_since_last_record

# %% [markdown]
# Os valores de score do modelo vão de 300 a 850, padrão utilizado por muitas empresas.

# %%
min_score = 300
max_score = 850

# %%
# agrupando dados e calculando o coeficiente mínimo de cada variável

df_scorecard.groupby('nome_original_feature')['coeficiente'].min()
# Out:
# nome_original_feature
# acc_now_delinq                 0.168730
# addr_state                     0.038921
# annual_inc                    -0.063282
# delinq_2yrs                    0.008231
# dti                           -0.001991
# emp_length                     0.058436
# grade                          0.181411
# home_ownership                 0.080838
# initial_list_status            0.069243
# inq_last_6mths                 0.386399
# int_rate                       0.096453
# intercept                     -1.371397
# mths_since_earliest_cr_line    0.047317
# mths_since_issue_d            -0.071832
# mths_since_last_delinq         0.043164
# mths_since_last_record         0.257033
# open_acc                      -0.186017
# pub_rec                        0.033668
# purpose                        0.189525
# term                           0.085792
# total_acc                     -0.034813
# total_rev_hi_lim              -0.011052
# verification_status            0.005561
# Name: coeficiente, dtype: float64

# %%
# soma dos coeficientes mínimos

min_sum_coef = df_scorecard.groupby('nome_original_feature')['coeficiente'].min().sum()
min_sum_coef
# Out:
# 0.01033829947715837

# %%
# agrupando dados e calculando os coeficientes máximos de cada variável

df_scorecard.groupby('nome_original_feature')['coeficiente'].max()
# Out:
# nome_original_feature
# acc_now_delinq                 0.168730
# addr_state                     0.448291
# annual_inc                     0.545912
# delinq_2yrs                    0.064171
# dti                            0.349212
# emp_length                     0.129819
# grade                          1.120239
# home_ownership                 0.118092
# initial_list_status            0.069243
# inq_last_6mths                 0.729960
# int_rate                       0.909501
# intercept                     -1.371397
# mths_since_earliest_cr_line    0.136221
# mths_since_issue_d             1.040987
# mths_since_last_delinq         0.110025
# mths_since_last_record         0.616042
# open_acc                      -0.064582
# pub_rec                        0.040164
# purpose                        0.302932
# term                           0.085792
# total_acc                     -0.018672
# total_rev_hi_lim               0.202200
# verification_status            0.108887
# Name: coeficiente, dtype: float64

# %%
# soma dos coeficientes máximos

max_sum_coef = df_scorecard.groupby('nome_original_feature')['coeficiente'].max().sum()
max_sum_coef
# Out:
# 5.841769670503259

# %% [markdown]
# Reescalando coeficientes de cada variável para um score correspondente.

# %%
# multiplicação do valor da coluna coeficientes pela razão das diferenças entre
# pontuação máxima e pontuação mínima e soma máxima e soma mínima dos coeficientes

df_scorecard['calculo_score'] = df_scorecard['coeficiente'] * (max_score - min_score) / (max_sum_coef - min_sum_coef)
df_scorecard
# Out:
#      index                         nome_feature  coeficiente        p_valor  \
# 0        0                            intercept    -1.371397            NaN
# 1        1                              grade:A     1.120239   1.705517e-30
# 2        2                              grade:B     0.891872   1.198637e-42
# 3        3                              grade:C     0.706093   1.383027e-31
# 4        4                              grade:D     0.529578   2.517464e-20
# 5        5                              grade:E     0.344007   1.869595e-11
# 6        6                              grade:F     0.181411   6.870495e-04
# 7        7                   home_ownership:OWN     0.080838   1.659498e-04
# 8        8              home_ownership:MORTGAGE     0.118092   3.618968e-18
# 9        9                     addr_state:NM_VA     0.038921   2.552631e-01
# 10      10                        addr_state:NY     0.061426   1.807077e-02
# 11      11         addr_state:OK_TN_MO_LA_MD_NC     0.055567   2.495962e-02
# 12      12                        addr_state:CA     0.066356   3.495677e-03
# 13      13               addr_state:UT_KY_AZ_NJ     0.075903   4.320970e-03
# 14      14            addr_state:AR_MI_PA_OH_MN     0.140124   6.295668e-09
# 15      15            addr_state:RI_MA_DE_SD_IN     0.091620   4.048894e-03
# 16      16                  addr_state:GA_WA_OR     0.209991   2.350712e-13
# 17      17                     addr_state:WI_MT     0.263169   2.998592e-07
# 18      18                        addr_state:TX     0.213835   1.349446e-14
# 19      19                     addr_state:IL_CT     0.275203   1.639024e-18
# 20      20         addr_state:KS_SC_CO_VT_AK_MS     0.302989   3.206527e-20
# 21      21         addr_state:WV_NH_WY_DC_ME_ID     0.448291   5.728476e-16
# 22      22     verification_status:Not Verified     0.108887   4.650683e-12
# 23      23  verification_status:Source Verified     0.005561   6.987679e-01
# 24      24                  purpose:credit_card     0.302932   2.090231e-23
# 25      25           purpose:debt_consolidation     0.189525   1.130595e-11
# 26      26           purpose:oth__med__vacation     0.192464   7.409649e-09
# 27      27  purpose:major_purch__car__home_impr     0.247194   1.573550e-13
# 28      28                initial_list_status:w     0.069243   7.285469e-07
# 29      29                              term:36     0.085792   1.492822e-08
# 30      30                         emp_length:1     0.112939   5.022189e-05
# 31      31                       emp_length:2-4     0.126190   4.443237e-10
# 32      32                       emp_length:5-6     0.076540   8.095626e-04
# 33      33                       emp_length:7-9     0.058436   8.725434e-03
# 34      34                        emp_length:10     0.129819   5.004927e-11
# 35      35               mths_since_issue_d:<38     1.040987  4.818019e-142
# 36      36             mths_since_issue_d:38-39     0.874636  5.561227e-123
# 37      37             mths_since_issue_d:40-41     0.776557  9.703474e-102
# 38      38             mths_since_issue_d:42-48     0.556012   3.875045e-67
# 39      39             mths_since_issue_d:49-52     0.419556   1.706727e-34
# 40      40             mths_since_issue_d:53-64     0.184479   1.091953e-08
# 41      41             mths_since_issue_d:65-84    -0.071832   2.221073e-02
# 42      42                      int_rate:<9.548     0.909501   1.862597e-28
# 43      43                int_rate:9.548-12.025     0.577437   2.684331e-33
# 44      44                int_rate:12.025-15.74     0.305270   1.004183e-14
# 45      45                int_rate:15.74-20.281     0.096453   1.894529e-03
# 46      46  mths_since_earliest_cr_line:141-164     0.076505   4.289903e-03
# 47      47  mths_since_earliest_cr_line:165-247     0.047317   2.945645e-02
# 48      48  mths_since_earliest_cr_line:248-270     0.074403   8.673981e-03
# 49      49  mths_since_earliest_cr_line:271-352     0.136221   9.650868e-08
# 50      50     mths_since_earliest_cr_line:>352     0.133434   3.864068e-06
# 51      51                        delinq_2yrs:0     0.064171   2.913999e-01
# 52      52                      delinq_2yrs:1-3     0.008231   8.854481e-01
# 53      53                     inq_last_6mths:0     0.729960   3.825313e-09
# 54      54                   inq_last_6mths:1-2     0.587147   2.077073e-06
# 55      55                   inq_last_6mths:3-6     0.386399   1.872395e-03
# 56      56                         open_acc:1-3    -0.064582   7.185561e-01
# 57      57                        open_acc:4-12    -0.126531   4.704781e-01
# 58      58                       open_acc:13-17    -0.137366   4.342373e-01
# 59      59                       open_acc:18-22    -0.159259   3.673023e-01
# 60      60                       open_acc:23-25    -0.136569   4.527126e-01
# 61      61                       open_acc:26-30    -0.150296   4.212804e-01
# 62      62                        open_acc:>=31    -0.186017   3.564643e-01
# 63      63                          pub_rec:3-4     0.033668   7.305199e-01
# 64      64                          pub_rec:>=5     0.040164   8.330900e-01
# 65      65                      total_acc:28-51    -0.018672   2.191139e-01
# 66      66                       total_acc:>=52    -0.034813   4.048570e-01
# 67      67                   acc_now_delinq:>=1     0.168730   1.327620e-01
# 68      68              total_rev_hi_lim:5K-10K     0.013172   6.176985e-01
# 69      69             total_rev_hi_lim:10K-20K    -0.000652   9.796862e-01
# 70      70             total_rev_hi_lim:20K-30K     0.005408   8.477255e-01
# 71      71             total_rev_hi_lim:30K-40K    -0.011052   7.258825e-01
# 72      72             total_rev_hi_lim:40K-55K     0.041321   2.307736e-01
# 73      73             total_rev_hi_lim:55K-95K     0.063422   9.999395e-02
# 74      74                total_rev_hi_lim:>95K     0.202200   7.614600e-04
# 75      75                   annual_inc:20K-30K    -0.063282   1.685759e-01
# 76      76                   annual_inc:30K-40K    -0.007194   8.712086e-01
# 77      77                   annual_inc:40K-50K     0.107380   1.572607e-02
# 78      78                   annual_inc:50K-60K     0.151162   7.886802e-04
# 79      79                   annual_inc:60K-70K     0.237277   2.708393e-07
# 80      80                   annual_inc:70K-80K     0.298050   2.431056e-10
# 81      81                   annual_inc:80K-90K     0.384270   4.726272e-15
# 82      82                  annual_inc:90K-100K     0.398392   3.878425e-15
# 83      83                 annual_inc:100K-120K     0.454093   1.786500e-19
# 84      84                 annual_inc:120K-140K     0.545912   8.986038e-22
# 85      85                     annual_inc:>140K     0.469262   6.838232e-19
# 86      86                            dti:<=1.4     0.247248   1.002660e-02
# 87      87                          dti:1.4-3.5     0.349212   1.678895e-05
# 88      88                          dti:3.5-7.7     0.309396   1.191862e-05
# 89      89                         dti:7.7-10.5     0.261016   1.964027e-04
# 90      90                        dti:10.5-16.1     0.186179   6.195766e-03
# 91      91                        dti:16.1-20.3     0.097779   1.503448e-01
# 92      92                        dti:20.3-21.7     0.093219   1.865510e-01
# 93      93                        dti:21.7-22.4     0.040482   5.872295e-01
# 94      94                          dti:22.4-35    -0.001991   9.763588e-01
# 95      95       mths_since_last_delinq:Missing     0.043164   4.867386e-01
# 96      96          mths_since_last_delinq:4-30     0.106192   6.470523e-02
# 97      97         mths_since_last_delinq:31-56     0.110025   8.165944e-02
# 98      98          mths_since_last_delinq:>=57     0.069058   2.835101e-01
# 99      99       mths_since_last_record:Missing     0.371095   5.331083e-05
# 100    100          mths_since_last_record:3-20     0.385860   3.406373e-03
# 101    101         mths_since_last_record:21-31     0.451669   3.166182e-04
# 102    102         mths_since_last_record:32-80     0.616042   1.622830e-10
# 103    103         mths_since_last_record:81-86     0.257033   2.331781e-02
# 104    104           mths_since_last_record:>86     0.318918   7.666102e-04
#
#            nome_original_feature  calculo_score
# 0                      intercept    -129.345317
# 1                          grade     105.657014
# 2                          grade      84.118238
# 3                          grade      66.596188
# 4                          grade      49.947893
# 5                          grade      32.445523
# 6                          grade      17.110003
# 7                 home_ownership       7.624322
# 8                 home_ownership      11.138061
# 9                     addr_state       3.670930
# 10                    addr_state       5.793474
# 11                    addr_state       5.240905
# 12                    addr_state       6.258459
# 13                    addr_state       7.158925
# 14                    addr_state      13.216036
# 15                    addr_state       8.641286
# 16                    addr_state      19.805597
# 17                    addr_state      24.821140
# 18                    addr_state      20.168155
# 19                    addr_state      25.956142
# 20                    addr_state      28.576881
# 21                    addr_state      42.281261
# 22           verification_status      10.269874
# 23           verification_status       0.524488
# 24                       purpose      28.571450
# 25                       purpose      17.875283
# 26                       purpose      18.152540
# 27                       purpose      23.314443
# 28           initial_list_status       6.530746
# 29                          term       8.091595
# 30                    emp_length      10.652024
# 31                    emp_length      11.901815
# 32                    emp_length       7.218996
# 33                    emp_length       5.511493
# 34                    emp_length      12.244097
# 35            mths_since_issue_d      98.182189
# 36            mths_since_issue_d      82.492537
# 37            mths_since_issue_d      73.242102
# 38            mths_since_issue_d      52.441044
# 39            mths_since_issue_d      39.571061
# 40            mths_since_issue_d      17.399386
# 41            mths_since_issue_d      -6.774941
# 42                      int_rate      85.780919
# 43                      int_rate      54.461777
# 44                      int_rate      28.792007
# 45                      int_rate       9.097142
# 46   mths_since_earliest_cr_line       7.215698
# 47   mths_since_earliest_cr_line       4.462802
# 48   mths_since_earliest_cr_line       7.017404
# 49   mths_since_earliest_cr_line      12.847902
# 50   mths_since_earliest_cr_line      12.585068
# 51                   delinq_2yrs       6.052356
# 52                   delinq_2yrs       0.776341
# 53                inq_last_6mths      68.847242
# 54                inq_last_6mths      55.377585
# 55                inq_last_6mths      36.443771
# 56                      open_acc      -6.091103
# 57                      open_acc     -11.933968
# 58                      open_acc     -12.955884
# 59                      open_acc     -15.020730
# 60                      open_acc     -12.880750
# 61                      open_acc     -14.175343
# 62                      open_acc     -17.544497
# 63                       pub_rec       3.175462
# 64                       pub_rec       3.788093
# 65                     total_acc      -1.761048
# 66                     total_acc      -3.283412
# 67                acc_now_delinq      15.914052
# 68              total_rev_hi_lim       1.242291
# 69              total_rev_hi_lim      -0.061540
# 70              total_rev_hi_lim       0.510099
# 71              total_rev_hi_lim      -1.042381
# 72              total_rev_hi_lim       3.897255
# 73              total_rev_hi_lim       5.981773
# 74              total_rev_hi_lim      19.070802
# 75                    annual_inc      -5.968510
# 76                    annual_inc      -0.678552
# 77                    annual_inc      10.127727
# 78                    annual_inc      14.257036
# 79                    annual_inc      22.379132
# 80                    annual_inc      28.110986
# 81                    annual_inc      36.242975
# 82                    annual_inc      37.574917
# 83                    annual_inc      42.828406
# 84                    annual_inc      51.488462
# 85                    annual_inc      44.259128
# 86                           dti      23.319593
# 87                           dti      32.936407
# 88                           dti      29.181160
# 89                           dti      24.618096
# 90                           dti      17.559791
# 91                           dti       9.222165
# 92                           dti       8.792124
# 93                           dti       3.818097
# 94                           dti      -0.187784
# 95        mths_since_last_delinq       4.071030
# 96        mths_since_last_delinq      10.015689
# 97        mths_since_last_delinq      10.377155
# 98        mths_since_last_delinq       6.513331
# 99        mths_since_last_record      35.000407
# 100       mths_since_last_record      36.392926
# 101       mths_since_last_record      42.599820
# 102       mths_since_last_record      58.102860
# 103       mths_since_last_record      24.242453
# 104       mths_since_last_record      30.079218

# %%
# divide-se a diferença do valor da coluna coeficientes e a soma mínima dos coeficientes pela
# diferença da soma máxima e a soma mínima dos coeficientes
# multiplica-se pela diferença entre a pontuação máxima e a pontuação mínima
# e adiciona-se a pontuação mínima

df_scorecard['calculo_score'][0] = ((df_scorecard['coeficiente'][0] - min_sum_coef) / (max_sum_coef - min_sum_coef)) * (max_score - min_score) + min_score
df_scorecard
# Out:
#      index                         nome_feature  coeficiente        p_valor  \
# 0        0                            intercept    -1.371397            NaN
# 1        1                              grade:A     1.120239   1.705517e-30
# 2        2                              grade:B     0.891872   1.198637e-42
# 3        3                              grade:C     0.706093   1.383027e-31
# 4        4                              grade:D     0.529578   2.517464e-20
# 5        5                              grade:E     0.344007   1.869595e-11
# 6        6                              grade:F     0.181411   6.870495e-04
# 7        7                   home_ownership:OWN     0.080838   1.659498e-04
# 8        8              home_ownership:MORTGAGE     0.118092   3.618968e-18
# 9        9                     addr_state:NM_VA     0.038921   2.552631e-01
# 10      10                        addr_state:NY     0.061426   1.807077e-02
# 11      11         addr_state:OK_TN_MO_LA_MD_NC     0.055567   2.495962e-02
# 12      12                        addr_state:CA     0.066356   3.495677e-03
# 13      13               addr_state:UT_KY_AZ_NJ     0.075903   4.320970e-03
# 14      14            addr_state:AR_MI_PA_OH_MN     0.140124   6.295668e-09
# 15      15            addr_state:RI_MA_DE_SD_IN     0.091620   4.048894e-03
# 16      16                  addr_state:GA_WA_OR     0.209991   2.350712e-13
# 17      17                     addr_state:WI_MT     0.263169   2.998592e-07
# 18      18                        addr_state:TX     0.213835   1.349446e-14
# 19      19                     addr_state:IL_CT     0.275203   1.639024e-18
# 20      20         addr_state:KS_SC_CO_VT_AK_MS     0.302989   3.206527e-20
# 21      21         addr_state:WV_NH_WY_DC_ME_ID     0.448291   5.728476e-16
# 22      22     verification_status:Not Verified     0.108887   4.650683e-12
# 23      23  verification_status:Source Verified     0.005561   6.987679e-01
# 24      24                  purpose:credit_card     0.302932   2.090231e-23
# 25      25           purpose:debt_consolidation     0.189525   1.130595e-11
# 26      26           purpose:oth__med__vacation     0.192464   7.409649e-09
# 27      27  purpose:major_purch__car__home_impr     0.247194   1.573550e-13
# 28      28                initial_list_status:w     0.069243   7.285469e-07
# 29      29                              term:36     0.085792   1.492822e-08
# 30      30                         emp_length:1     0.112939   5.022189e-05
# 31      31                       emp_length:2-4     0.126190   4.443237e-10
# 32      32                       emp_length:5-6     0.076540   8.095626e-04
# 33      33                       emp_length:7-9     0.058436   8.725434e-03
# 34      34                        emp_length:10     0.129819   5.004927e-11
# 35      35               mths_since_issue_d:<38     1.040987  4.818019e-142
# 36      36             mths_since_issue_d:38-39     0.874636  5.561227e-123
# 37      37             mths_since_issue_d:40-41     0.776557  9.703474e-102
# 38      38             mths_since_issue_d:42-48     0.556012   3.875045e-67
# 39      39             mths_since_issue_d:49-52     0.419556   1.706727e-34
# 40      40             mths_since_issue_d:53-64     0.184479   1.091953e-08
# 41      41             mths_since_issue_d:65-84    -0.071832   2.221073e-02
# 42      42                      int_rate:<9.548     0.909501   1.862597e-28
# 43      43                int_rate:9.548-12.025     0.577437   2.684331e-33
# 44      44                int_rate:12.025-15.74     0.305270   1.004183e-14
# 45      45                int_rate:15.74-20.281     0.096453   1.894529e-03
# 46      46  mths_since_earliest_cr_line:141-164     0.076505   4.289903e-03
# 47      47  mths_since_earliest_cr_line:165-247     0.047317   2.945645e-02
# 48      48  mths_since_earliest_cr_line:248-270     0.074403   8.673981e-03
# 49      49  mths_since_earliest_cr_line:271-352     0.136221   9.650868e-08
# 50      50     mths_since_earliest_cr_line:>352     0.133434   3.864068e-06
# 51      51                        delinq_2yrs:0     0.064171   2.913999e-01
# 52      52                      delinq_2yrs:1-3     0.008231   8.854481e-01
# 53      53                     inq_last_6mths:0     0.729960   3.825313e-09
# 54      54                   inq_last_6mths:1-2     0.587147   2.077073e-06
# 55      55                   inq_last_6mths:3-6     0.386399   1.872395e-03
# 56      56                         open_acc:1-3    -0.064582   7.185561e-01
# 57      57                        open_acc:4-12    -0.126531   4.704781e-01
# 58      58                       open_acc:13-17    -0.137366   4.342373e-01
# 59      59                       open_acc:18-22    -0.159259   3.673023e-01
# 60      60                       open_acc:23-25    -0.136569   4.527126e-01
# 61      61                       open_acc:26-30    -0.150296   4.212804e-01
# 62      62                        open_acc:>=31    -0.186017   3.564643e-01
# 63      63                          pub_rec:3-4     0.033668   7.305199e-01
# 64      64                          pub_rec:>=5     0.040164   8.330900e-01
# 65      65                      total_acc:28-51    -0.018672   2.191139e-01
# 66      66                       total_acc:>=52    -0.034813   4.048570e-01
# 67      67                   acc_now_delinq:>=1     0.168730   1.327620e-01
# 68      68              total_rev_hi_lim:5K-10K     0.013172   6.176985e-01
# 69      69             total_rev_hi_lim:10K-20K    -0.000652   9.796862e-01
# 70      70             total_rev_hi_lim:20K-30K     0.005408   8.477255e-01
# 71      71             total_rev_hi_lim:30K-40K    -0.011052   7.258825e-01
# 72      72             total_rev_hi_lim:40K-55K     0.041321   2.307736e-01
# 73      73             total_rev_hi_lim:55K-95K     0.063422   9.999395e-02
# 74      74                total_rev_hi_lim:>95K     0.202200   7.614600e-04
# 75      75                   annual_inc:20K-30K    -0.063282   1.685759e-01
# 76      76                   annual_inc:30K-40K    -0.007194   8.712086e-01
# 77      77                   annual_inc:40K-50K     0.107380   1.572607e-02
# 78      78                   annual_inc:50K-60K     0.151162   7.886802e-04
# 79      79                   annual_inc:60K-70K     0.237277   2.708393e-07
# 80      80                   annual_inc:70K-80K     0.298050   2.431056e-10
# 81      81                   annual_inc:80K-90K     0.384270   4.726272e-15
# 82      82                  annual_inc:90K-100K     0.398392   3.878425e-15
# 83      83                 annual_inc:100K-120K     0.454093   1.786500e-19
# 84      84                 annual_inc:120K-140K     0.545912   8.986038e-22
# 85      85                     annual_inc:>140K     0.469262   6.838232e-19
# 86      86                            dti:<=1.4     0.247248   1.002660e-02
# 87      87                          dti:1.4-3.5     0.349212   1.678895e-05
# 88      88                          dti:3.5-7.7     0.309396   1.191862e-05
# 89      89                         dti:7.7-10.5     0.261016   1.964027e-04
# 90      90                        dti:10.5-16.1     0.186179   6.195766e-03
# 91      91                        dti:16.1-20.3     0.097779   1.503448e-01
# 92      92                        dti:20.3-21.7     0.093219   1.865510e-01
# 93      93                        dti:21.7-22.4     0.040482   5.872295e-01
# 94      94                          dti:22.4-35    -0.001991   9.763588e-01
# 95      95       mths_since_last_delinq:Missing     0.043164   4.867386e-01
# 96      96          mths_since_last_delinq:4-30     0.106192   6.470523e-02
# 97      97         mths_since_last_delinq:31-56     0.110025   8.165944e-02
# 98      98          mths_since_last_delinq:>=57     0.069058   2.835101e-01
# 99      99       mths_since_last_record:Missing     0.371095   5.331083e-05
# 100    100          mths_since_last_record:3-20     0.385860   3.406373e-03
# 101    101         mths_since_last_record:21-31     0.451669   3.166182e-04
# 102    102         mths_since_last_record:32-80     0.616042   1.622830e-10
# 103    103         mths_since_last_record:81-86     0.257033   2.331781e-02
# 104    104           mths_since_last_record:>86     0.318918   7.666102e-04
#
#            nome_original_feature  calculo_score
# 0                      intercept     169.679612
# 1                          grade     105.657014
# 2                          grade      84.118238
# 3                          grade      66.596188
# 4                          grade      49.947893
# 5                          grade      32.445523
# 6                          grade      17.110003
# 7                 home_ownership       7.624322
# 8                 home_ownership      11.138061
# 9                     addr_state       3.670930
# 10                    addr_state       5.793474
# 11                    addr_state       5.240905
# 12                    addr_state       6.258459
# 13                    addr_state       7.158925
# 14                    addr_state      13.216036
# 15                    addr_state       8.641286
# 16                    addr_state      19.805597
# 17                    addr_state      24.821140
# 18                    addr_state      20.168155
# 19                    addr_state      25.956142
# 20                    addr_state      28.576881
# 21                    addr_state      42.281261
# 22           verification_status      10.269874
# 23           verification_status       0.524488
# 24                       purpose      28.571450
# 25                       purpose      17.875283
# 26                       purpose      18.152540
# 27                       purpose      23.314443
# 28           initial_list_status       6.530746
# 29                          term       8.091595
# 30                    emp_length      10.652024
# 31                    emp_length      11.901815
# 32                    emp_length       7.218996
# 33                    emp_length       5.511493
# 34                    emp_length      12.244097
# 35            mths_since_issue_d      98.182189
# 36            mths_since_issue_d      82.492537
# 37            mths_since_issue_d      73.242102
# 38            mths_since_issue_d      52.441044
# 39            mths_since_issue_d      39.571061
# 40            mths_since_issue_d      17.399386
# 41            mths_since_issue_d      -6.774941
# 42                      int_rate      85.780919
# 43                      int_rate      54.461777
# 44                      int_rate      28.792007
# 45                      int_rate       9.097142
# 46   mths_since_earliest_cr_line       7.215698
# 47   mths_since_earliest_cr_line       4.462802
# 48   mths_since_earliest_cr_line       7.017404
# 49   mths_since_earliest_cr_line      12.847902
# 50   mths_since_earliest_cr_line      12.585068
# 51                   delinq_2yrs       6.052356
# 52                   delinq_2yrs       0.776341
# 53                inq_last_6mths      68.847242
# 54                inq_last_6mths      55.377585
# 55                inq_last_6mths      36.443771
# 56                      open_acc      -6.091103
# 57                      open_acc     -11.933968
# 58                      open_acc     -12.955884
# 59                      open_acc     -15.020730
# 60                      open_acc     -12.880750
# 61                      open_acc     -14.175343
# 62                      open_acc     -17.544497
# 63                       pub_rec       3.175462
# 64                       pub_rec       3.788093
# 65                     total_acc      -1.761048
# 66                     total_acc      -3.283412
# 67                acc_now_delinq      15.914052
# 68              total_rev_hi_lim       1.242291
# 69              total_rev_hi_lim      -0.061540
# 70              total_rev_hi_lim       0.510099
# 71              total_rev_hi_lim      -1.042381
# 72              total_rev_hi_lim       3.897255
# 73              total_rev_hi_lim       5.981773
# 74              total_rev_hi_lim      19.070802
# 75                    annual_inc      -5.968510
# 76                    annual_inc      -0.678552
# 77                    annual_inc      10.127727
# 78                    annual_inc      14.257036
# 79                    annual_inc      22.379132
# 80                    annual_inc      28.110986
# 81                    annual_inc      36.242975
# 82                    annual_inc      37.574917
# 83                    annual_inc      42.828406
# 84                    annual_inc      51.488462
# 85                    annual_inc      44.259128
# 86                           dti      23.319593
# 87                           dti      32.936407
# 88                           dti      29.181160
# 89                           dti      24.618096
# 90                           dti      17.559791
# 91                           dti       9.222165
# 92                           dti       8.792124
# 93                           dti       3.818097
# 94                           dti      -0.187784
# 95        mths_since_last_delinq       4.071030
# 96        mths_since_last_delinq      10.015689
# 97        mths_since_last_delinq      10.377155
# 98        mths_since_last_delinq       6.513331
# 99        mths_since_last_record      35.000407
# 100       mths_since_last_record      36.392926
# 101       mths_since_last_record      42.599820
# 102       mths_since_last_record      58.102860
# 103       mths_since_last_record      24.242453
# 104       mths_since_last_record      30.079218

# %%
# arrendondando o valor do score

df_scorecard['score_preliminar'] = df_scorecard['calculo_score'].round()
df_scorecard
# Out:
#      index                         nome_feature  coeficiente        p_valor  \
# 0        0                            intercept    -1.371397            NaN
# 1        1                              grade:A     1.120239   1.705517e-30
# 2        2                              grade:B     0.891872   1.198637e-42
# 3        3                              grade:C     0.706093   1.383027e-31
# 4        4                              grade:D     0.529578   2.517464e-20
# 5        5                              grade:E     0.344007   1.869595e-11
# 6        6                              grade:F     0.181411   6.870495e-04
# 7        7                   home_ownership:OWN     0.080838   1.659498e-04
# 8        8              home_ownership:MORTGAGE     0.118092   3.618968e-18
# 9        9                     addr_state:NM_VA     0.038921   2.552631e-01
# 10      10                        addr_state:NY     0.061426   1.807077e-02
# 11      11         addr_state:OK_TN_MO_LA_MD_NC     0.055567   2.495962e-02
# 12      12                        addr_state:CA     0.066356   3.495677e-03
# 13      13               addr_state:UT_KY_AZ_NJ     0.075903   4.320970e-03
# 14      14            addr_state:AR_MI_PA_OH_MN     0.140124   6.295668e-09
# 15      15            addr_state:RI_MA_DE_SD_IN     0.091620   4.048894e-03
# 16      16                  addr_state:GA_WA_OR     0.209991   2.350712e-13
# 17      17                     addr_state:WI_MT     0.263169   2.998592e-07
# 18      18                        addr_state:TX     0.213835   1.349446e-14
# 19      19                     addr_state:IL_CT     0.275203   1.639024e-18
# 20      20         addr_state:KS_SC_CO_VT_AK_MS     0.302989   3.206527e-20
# 21      21         addr_state:WV_NH_WY_DC_ME_ID     0.448291   5.728476e-16
# 22      22     verification_status:Not Verified     0.108887   4.650683e-12
# 23      23  verification_status:Source Verified     0.005561   6.987679e-01
# 24      24                  purpose:credit_card     0.302932   2.090231e-23
# 25      25           purpose:debt_consolidation     0.189525   1.130595e-11
# 26      26           purpose:oth__med__vacation     0.192464   7.409649e-09
# 27      27  purpose:major_purch__car__home_impr     0.247194   1.573550e-13
# 28      28                initial_list_status:w     0.069243   7.285469e-07
# 29      29                              term:36     0.085792   1.492822e-08
# 30      30                         emp_length:1     0.112939   5.022189e-05
# 31      31                       emp_length:2-4     0.126190   4.443237e-10
# 32      32                       emp_length:5-6     0.076540   8.095626e-04
# 33      33                       emp_length:7-9     0.058436   8.725434e-03
# 34      34                        emp_length:10     0.129819   5.004927e-11
# 35      35               mths_since_issue_d:<38     1.040987  4.818019e-142
# 36      36             mths_since_issue_d:38-39     0.874636  5.561227e-123
# 37      37             mths_since_issue_d:40-41     0.776557  9.703474e-102
# 38      38             mths_since_issue_d:42-48     0.556012   3.875045e-67
# 39      39             mths_since_issue_d:49-52     0.419556   1.706727e-34
# 40      40             mths_since_issue_d:53-64     0.184479   1.091953e-08
# 41      41             mths_since_issue_d:65-84    -0.071832   2.221073e-02
# 42      42                      int_rate:<9.548     0.909501   1.862597e-28
# 43      43                int_rate:9.548-12.025     0.577437   2.684331e-33
# 44      44                int_rate:12.025-15.74     0.305270   1.004183e-14
# 45      45                int_rate:15.74-20.281     0.096453   1.894529e-03
# 46      46  mths_since_earliest_cr_line:141-164     0.076505   4.289903e-03
# 47      47  mths_since_earliest_cr_line:165-247     0.047317   2.945645e-02
# 48      48  mths_since_earliest_cr_line:248-270     0.074403   8.673981e-03
# 49      49  mths_since_earliest_cr_line:271-352     0.136221   9.650868e-08
# 50      50     mths_since_earliest_cr_line:>352     0.133434   3.864068e-06
# 51      51                        delinq_2yrs:0     0.064171   2.913999e-01
# 52      52                      delinq_2yrs:1-3     0.008231   8.854481e-01
# 53      53                     inq_last_6mths:0     0.729960   3.825313e-09
# 54      54                   inq_last_6mths:1-2     0.587147   2.077073e-06
# 55      55                   inq_last_6mths:3-6     0.386399   1.872395e-03
# 56      56                         open_acc:1-3    -0.064582   7.185561e-01
# 57      57                        open_acc:4-12    -0.126531   4.704781e-01
# 58      58                       open_acc:13-17    -0.137366   4.342373e-01
# 59      59                       open_acc:18-22    -0.159259   3.673023e-01
# 60      60                       open_acc:23-25    -0.136569   4.527126e-01
# 61      61                       open_acc:26-30    -0.150296   4.212804e-01
# 62      62                        open_acc:>=31    -0.186017   3.564643e-01
# 63      63                          pub_rec:3-4     0.033668   7.305199e-01
# 64      64                          pub_rec:>=5     0.040164   8.330900e-01
# 65      65                      total_acc:28-51    -0.018672   2.191139e-01
# 66      66                       total_acc:>=52    -0.034813   4.048570e-01
# 67      67                   acc_now_delinq:>=1     0.168730   1.327620e-01
# 68      68              total_rev_hi_lim:5K-10K     0.013172   6.176985e-01
# 69      69             total_rev_hi_lim:10K-20K    -0.000652   9.796862e-01
# 70      70             total_rev_hi_lim:20K-30K     0.005408   8.477255e-01
# 71      71             total_rev_hi_lim:30K-40K    -0.011052   7.258825e-01
# 72      72             total_rev_hi_lim:40K-55K     0.041321   2.307736e-01
# 73      73             total_rev_hi_lim:55K-95K     0.063422   9.999395e-02
# 74      74                total_rev_hi_lim:>95K     0.202200   7.614600e-04
# 75      75                   annual_inc:20K-30K    -0.063282   1.685759e-01
# 76      76                   annual_inc:30K-40K    -0.007194   8.712086e-01
# 77      77                   annual_inc:40K-50K     0.107380   1.572607e-02
# 78      78                   annual_inc:50K-60K     0.151162   7.886802e-04
# 79      79                   annual_inc:60K-70K     0.237277   2.708393e-07
# 80      80                   annual_inc:70K-80K     0.298050   2.431056e-10
# 81      81                   annual_inc:80K-90K     0.384270   4.726272e-15
# 82      82                  annual_inc:90K-100K     0.398392   3.878425e-15
# 83      83                 annual_inc:100K-120K     0.454093   1.786500e-19
# 84      84                 annual_inc:120K-140K     0.545912   8.986038e-22
# 85      85                     annual_inc:>140K     0.469262   6.838232e-19
# 86      86                            dti:<=1.4     0.247248   1.002660e-02
# 87      87                          dti:1.4-3.5     0.349212   1.678895e-05
# 88      88                          dti:3.5-7.7     0.309396   1.191862e-05
# 89      89                         dti:7.7-10.5     0.261016   1.964027e-04
# 90      90                        dti:10.5-16.1     0.186179   6.195766e-03
# 91      91                        dti:16.1-20.3     0.097779   1.503448e-01
# 92      92                        dti:20.3-21.7     0.093219   1.865510e-01
# 93      93                        dti:21.7-22.4     0.040482   5.872295e-01
# 94      94                          dti:22.4-35    -0.001991   9.763588e-01
# 95      95       mths_since_last_delinq:Missing     0.043164   4.867386e-01
# 96      96          mths_since_last_delinq:4-30     0.106192   6.470523e-02
# 97      97         mths_since_last_delinq:31-56     0.110025   8.165944e-02
# 98      98          mths_since_last_delinq:>=57     0.069058   2.835101e-01
# 99      99       mths_since_last_record:Missing     0.371095   5.331083e-05
# 100    100          mths_since_last_record:3-20     0.385860   3.406373e-03
# 101    101         mths_since_last_record:21-31     0.451669   3.166182e-04
# 102    102         mths_since_last_record:32-80     0.616042   1.622830e-10
# 103    103         mths_since_last_record:81-86     0.257033   2.331781e-02
# 104    104           mths_since_last_record:>86     0.318918   7.666102e-04
#
#            nome_original_feature  calculo_score  score_preliminar
# 0                      intercept     169.679612             170.0
# 1                          grade     105.657014             106.0
# 2                          grade      84.118238              84.0
# 3                          grade      66.596188              67.0
# 4                          grade      49.947893              50.0
# 5                          grade      32.445523              32.0
# 6                          grade      17.110003              17.0
# 7                 home_ownership       7.624322               8.0
# 8                 home_ownership      11.138061              11.0
# 9                     addr_state       3.670930               4.0
# 10                    addr_state       5.793474               6.0
# 11                    addr_state       5.240905               5.0
# 12                    addr_state       6.258459               6.0
# 13                    addr_state       7.158925               7.0
# 14                    addr_state      13.216036              13.0
# 15                    addr_state       8.641286               9.0
# 16                    addr_state      19.805597              20.0
# 17                    addr_state      24.821140              25.0
# 18                    addr_state      20.168155              20.0
# 19                    addr_state      25.956142              26.0
# 20                    addr_state      28.576881              29.0
# 21                    addr_state      42.281261              42.0
# 22           verification_status      10.269874              10.0
# 23           verification_status       0.524488               1.0
# 24                       purpose      28.571450              29.0
# 25                       purpose      17.875283              18.0
# 26                       purpose      18.152540              18.0
# 27                       purpose      23.314443              23.0
# 28           initial_list_status       6.530746               7.0
# 29                          term       8.091595               8.0
# 30                    emp_length      10.652024              11.0
# 31                    emp_length      11.901815              12.0
# 32                    emp_length       7.218996               7.0
# 33                    emp_length       5.511493               6.0
# 34                    emp_length      12.244097              12.0
# 35            mths_since_issue_d      98.182189              98.0
# 36            mths_since_issue_d      82.492537              82.0
# 37            mths_since_issue_d      73.242102              73.0
# 38            mths_since_issue_d      52.441044              52.0
# 39            mths_since_issue_d      39.571061              40.0
# 40            mths_since_issue_d      17.399386              17.0
# 41            mths_since_issue_d      -6.774941              -7.0
# 42                      int_rate      85.780919              86.0
# 43                      int_rate      54.461777              54.0
# 44                      int_rate      28.792007              29.0
# 45                      int_rate       9.097142               9.0
# 46   mths_since_earliest_cr_line       7.215698               7.0
# 47   mths_since_earliest_cr_line       4.462802               4.0
# 48   mths_since_earliest_cr_line       7.017404               7.0
# 49   mths_since_earliest_cr_line      12.847902              13.0
# 50   mths_since_earliest_cr_line      12.585068              13.0
# 51                   delinq_2yrs       6.052356               6.0
# 52                   delinq_2yrs       0.776341               1.0
# 53                inq_last_6mths      68.847242              69.0
# 54                inq_last_6mths      55.377585              55.0
# 55                inq_last_6mths      36.443771              36.0
# 56                      open_acc      -6.091103              -6.0
# 57                      open_acc     -11.933968             -12.0
# 58                      open_acc     -12.955884             -13.0
# 59                      open_acc     -15.020730             -15.0
# 60                      open_acc     -12.880750             -13.0
# 61                      open_acc     -14.175343             -14.0
# 62                      open_acc     -17.544497             -18.0
# 63                       pub_rec       3.175462               3.0
# 64                       pub_rec       3.788093               4.0
# 65                     total_acc      -1.761048              -2.0
# 66                     total_acc      -3.283412              -3.0
# 67                acc_now_delinq      15.914052              16.0
# 68              total_rev_hi_lim       1.242291               1.0
# 69              total_rev_hi_lim      -0.061540              -0.0
# 70              total_rev_hi_lim       0.510099               1.0
# 71              total_rev_hi_lim      -1.042381              -1.0
# 72              total_rev_hi_lim       3.897255               4.0
# 73              total_rev_hi_lim       5.981773               6.0
# 74              total_rev_hi_lim      19.070802              19.0
# 75                    annual_inc      -5.968510              -6.0
# 76                    annual_inc      -0.678552              -1.0
# 77                    annual_inc      10.127727              10.0
# 78                    annual_inc      14.257036              14.0
# 79                    annual_inc      22.379132              22.0
# 80                    annual_inc      28.110986              28.0
# 81                    annual_inc      36.242975              36.0
# 82                    annual_inc      37.574917              38.0
# 83                    annual_inc      42.828406              43.0
# 84                    annual_inc      51.488462              51.0
# 85                    annual_inc      44.259128              44.0
# 86                           dti      23.319593              23.0
# 87                           dti      32.936407              33.0
# 88                           dti      29.181160              29.0
# 89                           dti      24.618096              25.0
# 90                           dti      17.559791              18.0
# 91                           dti       9.222165               9.0
# 92                           dti       8.792124               9.0
# 93                           dti       3.818097               4.0
# 94                           dti      -0.187784              -0.0
# 95        mths_since_last_delinq       4.071030               4.0
# 96        mths_since_last_delinq      10.015689              10.0
# 97        mths_since_last_delinq      10.377155              10.0
# 98        mths_since_last_delinq       6.513331               7.0
# 99        mths_since_last_record      35.000407              35.0
# 100       mths_since_last_record      36.392926              36.0
# 101       mths_since_last_record      42.599820              43.0
# 102       mths_since_last_record      58.102860              58.0
# 103       mths_since_last_record      24.242453              24.0
# 104       mths_since_last_record      30.079218              30.0

# %%
# soma de todos os valores mínimos dos valores da coluna coeficiente
# score não está dentro da faixa escolhida

min_sum_score_prel = df_scorecard.groupby('nome_original_feature')['score_preliminar'].min().sum()
min_sum_score_prel
# Out:
# 301.0

# %%
# soma de todos os valores máximos dos valores da coluna coeficiente

max_sum_score_prel = df_scorecard.groupby('nome_original_feature')['score_preliminar'].max().sum()
max_sum_score_prel
# Out:
# 850.0

# %%
df_scorecard['diferenca'] = df_scorecard['score_preliminar'] - df_scorecard['calculo_score']
df_scorecard
# Out:
#      index                         nome_feature  coeficiente        p_valor  \
# 0        0                            intercept    -1.371397            NaN
# 1        1                              grade:A     1.120239   1.705517e-30
# 2        2                              grade:B     0.891872   1.198637e-42
# 3        3                              grade:C     0.706093   1.383027e-31
# 4        4                              grade:D     0.529578   2.517464e-20
# 5        5                              grade:E     0.344007   1.869595e-11
# 6        6                              grade:F     0.181411   6.870495e-04
# 7        7                   home_ownership:OWN     0.080838   1.659498e-04
# 8        8              home_ownership:MORTGAGE     0.118092   3.618968e-18
# 9        9                     addr_state:NM_VA     0.038921   2.552631e-01
# 10      10                        addr_state:NY     0.061426   1.807077e-02
# 11      11         addr_state:OK_TN_MO_LA_MD_NC     0.055567   2.495962e-02
# 12      12                        addr_state:CA     0.066356   3.495677e-03
# 13      13               addr_state:UT_KY_AZ_NJ     0.075903   4.320970e-03
# 14      14            addr_state:AR_MI_PA_OH_MN     0.140124   6.295668e-09
# 15      15            addr_state:RI_MA_DE_SD_IN     0.091620   4.048894e-03
# 16      16                  addr_state:GA_WA_OR     0.209991   2.350712e-13
# 17      17                     addr_state:WI_MT     0.263169   2.998592e-07
# 18      18                        addr_state:TX     0.213835   1.349446e-14
# 19      19                     addr_state:IL_CT     0.275203   1.639024e-18
# 20      20         addr_state:KS_SC_CO_VT_AK_MS     0.302989   3.206527e-20
# 21      21         addr_state:WV_NH_WY_DC_ME_ID     0.448291   5.728476e-16
# 22      22     verification_status:Not Verified     0.108887   4.650683e-12
# 23      23  verification_status:Source Verified     0.005561   6.987679e-01
# 24      24                  purpose:credit_card     0.302932   2.090231e-23
# 25      25           purpose:debt_consolidation     0.189525   1.130595e-11
# 26      26           purpose:oth__med__vacation     0.192464   7.409649e-09
# 27      27  purpose:major_purch__car__home_impr     0.247194   1.573550e-13
# 28      28                initial_list_status:w     0.069243   7.285469e-07
# 29      29                              term:36     0.085792   1.492822e-08
# 30      30                         emp_length:1     0.112939   5.022189e-05
# 31      31                       emp_length:2-4     0.126190   4.443237e-10
# 32      32                       emp_length:5-6     0.076540   8.095626e-04
# 33      33                       emp_length:7-9     0.058436   8.725434e-03
# 34      34                        emp_length:10     0.129819   5.004927e-11
# 35      35               mths_since_issue_d:<38     1.040987  4.818019e-142
# 36      36             mths_since_issue_d:38-39     0.874636  5.561227e-123
# 37      37             mths_since_issue_d:40-41     0.776557  9.703474e-102
# 38      38             mths_since_issue_d:42-48     0.556012   3.875045e-67
# 39      39             mths_since_issue_d:49-52     0.419556   1.706727e-34
# 40      40             mths_since_issue_d:53-64     0.184479   1.091953e-08
# 41      41             mths_since_issue_d:65-84    -0.071832   2.221073e-02
# 42      42                      int_rate:<9.548     0.909501   1.862597e-28
# 43      43                int_rate:9.548-12.025     0.577437   2.684331e-33
# 44      44                int_rate:12.025-15.74     0.305270   1.004183e-14
# 45      45                int_rate:15.74-20.281     0.096453   1.894529e-03
# 46      46  mths_since_earliest_cr_line:141-164     0.076505   4.289903e-03
# 47      47  mths_since_earliest_cr_line:165-247     0.047317   2.945645e-02
# 48      48  mths_since_earliest_cr_line:248-270     0.074403   8.673981e-03
# 49      49  mths_since_earliest_cr_line:271-352     0.136221   9.650868e-08
# 50      50     mths_since_earliest_cr_line:>352     0.133434   3.864068e-06
# 51      51                        delinq_2yrs:0     0.064171   2.913999e-01
# 52      52                      delinq_2yrs:1-3     0.008231   8.854481e-01
# 53      53                     inq_last_6mths:0     0.729960   3.825313e-09
# 54      54                   inq_last_6mths:1-2     0.587147   2.077073e-06
# 55      55                   inq_last_6mths:3-6     0.386399   1.872395e-03
# 56      56                         open_acc:1-3    -0.064582   7.185561e-01
# 57      57                        open_acc:4-12    -0.126531   4.704781e-01
# 58      58                       open_acc:13-17    -0.137366   4.342373e-01
# 59      59                       open_acc:18-22    -0.159259   3.673023e-01
# 60      60                       open_acc:23-25    -0.136569   4.527126e-01
# 61      61                       open_acc:26-30    -0.150296   4.212804e-01
# 62      62                        open_acc:>=31    -0.186017   3.564643e-01
# 63      63                          pub_rec:3-4     0.033668   7.305199e-01
# 64      64                          pub_rec:>=5     0.040164   8.330900e-01
# 65      65                      total_acc:28-51    -0.018672   2.191139e-01
# 66      66                       total_acc:>=52    -0.034813   4.048570e-01
# 67      67                   acc_now_delinq:>=1     0.168730   1.327620e-01
# 68      68              total_rev_hi_lim:5K-10K     0.013172   6.176985e-01
# 69      69             total_rev_hi_lim:10K-20K    -0.000652   9.796862e-01
# 70      70             total_rev_hi_lim:20K-30K     0.005408   8.477255e-01
# 71      71             total_rev_hi_lim:30K-40K    -0.011052   7.258825e-01
# 72      72             total_rev_hi_lim:40K-55K     0.041321   2.307736e-01
# 73      73             total_rev_hi_lim:55K-95K     0.063422   9.999395e-02
# 74      74                total_rev_hi_lim:>95K     0.202200   7.614600e-04
# 75      75                   annual_inc:20K-30K    -0.063282   1.685759e-01
# 76      76                   annual_inc:30K-40K    -0.007194   8.712086e-01
# 77      77                   annual_inc:40K-50K     0.107380   1.572607e-02
# 78      78                   annual_inc:50K-60K     0.151162   7.886802e-04
# 79      79                   annual_inc:60K-70K     0.237277   2.708393e-07
# 80      80                   annual_inc:70K-80K     0.298050   2.431056e-10
# 81      81                   annual_inc:80K-90K     0.384270   4.726272e-15
# 82      82                  annual_inc:90K-100K     0.398392   3.878425e-15
# 83      83                 annual_inc:100K-120K     0.454093   1.786500e-19
# 84      84                 annual_inc:120K-140K     0.545912   8.986038e-22
# 85      85                     annual_inc:>140K     0.469262   6.838232e-19
# 86      86                            dti:<=1.4     0.247248   1.002660e-02
# 87      87                          dti:1.4-3.5     0.349212   1.678895e-05
# 88      88                          dti:3.5-7.7     0.309396   1.191862e-05
# 89      89                         dti:7.7-10.5     0.261016   1.964027e-04
# 90      90                        dti:10.5-16.1     0.186179   6.195766e-03
# 91      91                        dti:16.1-20.3     0.097779   1.503448e-01
# 92      92                        dti:20.3-21.7     0.093219   1.865510e-01
# 93      93                        dti:21.7-22.4     0.040482   5.872295e-01
# 94      94                          dti:22.4-35    -0.001991   9.763588e-01
# 95      95       mths_since_last_delinq:Missing     0.043164   4.867386e-01
# 96      96          mths_since_last_delinq:4-30     0.106192   6.470523e-02
# 97      97         mths_since_last_delinq:31-56     0.110025   8.165944e-02
# 98      98          mths_since_last_delinq:>=57     0.069058   2.835101e-01
# 99      99       mths_since_last_record:Missing     0.371095   5.331083e-05
# 100    100          mths_since_last_record:3-20     0.385860   3.406373e-03
# 101    101         mths_since_last_record:21-31     0.451669   3.166182e-04
# 102    102         mths_since_last_record:32-80     0.616042   1.622830e-10
# 103    103         mths_since_last_record:81-86     0.257033   2.331781e-02
# 104    104           mths_since_last_record:>86     0.318918   7.666102e-04
#
#            nome_original_feature  calculo_score  score_preliminar  diferenca
# 0                      intercept     169.679612             170.0   0.320388
# 1                          grade     105.657014             106.0   0.342986
# 2                          grade      84.118238              84.0  -0.118238
# 3                          grade      66.596188              67.0   0.403812
# 4                          grade      49.947893              50.0   0.052107
# 5                          grade      32.445523              32.0  -0.445523
# 6                          grade      17.110003              17.0  -0.110003
# 7                 home_ownership       7.624322               8.0   0.375678
# 8                 home_ownership      11.138061              11.0  -0.138061
# 9                     addr_state       3.670930               4.0   0.329070
# 10                    addr_state       5.793474               6.0   0.206526
# 11                    addr_state       5.240905               5.0  -0.240905
# 12                    addr_state       6.258459               6.0  -0.258459
# 13                    addr_state       7.158925               7.0  -0.158925
# 14                    addr_state      13.216036              13.0  -0.216036
# 15                    addr_state       8.641286               9.0   0.358714
# 16                    addr_state      19.805597              20.0   0.194403
# 17                    addr_state      24.821140              25.0   0.178860
# 18                    addr_state      20.168155              20.0  -0.168155
# 19                    addr_state      25.956142              26.0   0.043858
# 20                    addr_state      28.576881              29.0   0.423119
# 21                    addr_state      42.281261              42.0  -0.281261
# 22           verification_status      10.269874              10.0  -0.269874
# 23           verification_status       0.524488               1.0   0.475512
# 24                       purpose      28.571450              29.0   0.428550
# 25                       purpose      17.875283              18.0   0.124717
# 26                       purpose      18.152540              18.0  -0.152540
# 27                       purpose      23.314443              23.0  -0.314443
# 28           initial_list_status       6.530746               7.0   0.469254
# 29                          term       8.091595               8.0  -0.091595
# 30                    emp_length      10.652024              11.0   0.347976
# 31                    emp_length      11.901815              12.0   0.098185
# 32                    emp_length       7.218996               7.0  -0.218996
# 33                    emp_length       5.511493               6.0   0.488507
# 34                    emp_length      12.244097              12.0  -0.244097
# 35            mths_since_issue_d      98.182189              98.0  -0.182189
# 36            mths_since_issue_d      82.492537              82.0  -0.492537
# 37            mths_since_issue_d      73.242102              73.0  -0.242102
# 38            mths_since_issue_d      52.441044              52.0  -0.441044
# 39            mths_since_issue_d      39.571061              40.0   0.428939
# 40            mths_since_issue_d      17.399386              17.0  -0.399386
# 41            mths_since_issue_d      -6.774941              -7.0  -0.225059
# 42                      int_rate      85.780919              86.0   0.219081
# 43                      int_rate      54.461777              54.0  -0.461777
# 44                      int_rate      28.792007              29.0   0.207993
# 45                      int_rate       9.097142               9.0  -0.097142
# 46   mths_since_earliest_cr_line       7.215698               7.0  -0.215698
# 47   mths_since_earliest_cr_line       4.462802               4.0  -0.462802
# 48   mths_since_earliest_cr_line       7.017404               7.0  -0.017404
# 49   mths_since_earliest_cr_line      12.847902              13.0   0.152098
# 50   mths_since_earliest_cr_line      12.585068              13.0   0.414932
# 51                   delinq_2yrs       6.052356               6.0  -0.052356
# 52                   delinq_2yrs       0.776341               1.0   0.223659
# 53                inq_last_6mths      68.847242              69.0   0.152758
# 54                inq_last_6mths      55.377585              55.0  -0.377585
# 55                inq_last_6mths      36.443771              36.0  -0.443771
# 56                      open_acc      -6.091103              -6.0   0.091103
# 57                      open_acc     -11.933968             -12.0  -0.066032
# 58                      open_acc     -12.955884             -13.0  -0.044116
# 59                      open_acc     -15.020730             -15.0   0.020730
# 60                      open_acc     -12.880750             -13.0  -0.119250
# 61                      open_acc     -14.175343             -14.0   0.175343
# 62                      open_acc     -17.544497             -18.0  -0.455503
# 63                       pub_rec       3.175462               3.0  -0.175462
# 64                       pub_rec       3.788093               4.0   0.211907
# 65                     total_acc      -1.761048              -2.0  -0.238952
# 66                     total_acc      -3.283412              -3.0   0.283412
# 67                acc_now_delinq      15.914052              16.0   0.085948
# 68              total_rev_hi_lim       1.242291               1.0  -0.242291
# 69              total_rev_hi_lim      -0.061540              -0.0   0.061540
# 70              total_rev_hi_lim       0.510099               1.0   0.489901
# 71              total_rev_hi_lim      -1.042381              -1.0   0.042381
# 72              total_rev_hi_lim       3.897255               4.0   0.102745
# 73              total_rev_hi_lim       5.981773               6.0   0.018227
# 74              total_rev_hi_lim      19.070802              19.0  -0.070802
# 75                    annual_inc      -5.968510              -6.0  -0.031490
# 76                    annual_inc      -0.678552              -1.0  -0.321448
# 77                    annual_inc      10.127727              10.0  -0.127727
# 78                    annual_inc      14.257036              14.0  -0.257036
# 79                    annual_inc      22.379132              22.0  -0.379132
# 80                    annual_inc      28.110986              28.0  -0.110986
# 81                    annual_inc      36.242975              36.0  -0.242975
# 82                    annual_inc      37.574917              38.0   0.425083
# 83                    annual_inc      42.828406              43.0   0.171594
# 84                    annual_inc      51.488462              51.0  -0.488462
# 85                    annual_inc      44.259128              44.0  -0.259128
# 86                           dti      23.319593              23.0  -0.319593
# 87                           dti      32.936407              33.0   0.063593
# 88                           dti      29.181160              29.0  -0.181160
# 89                           dti      24.618096              25.0   0.381904
# 90                           dti      17.559791              18.0   0.440209
# 91                           dti       9.222165               9.0  -0.222165
# 92                           dti       8.792124               9.0   0.207876
# 93                           dti       3.818097               4.0   0.181903
# 94                           dti      -0.187784              -0.0   0.187784
# 95        mths_since_last_delinq       4.071030               4.0  -0.071030
# 96        mths_since_last_delinq      10.015689              10.0  -0.015689
# 97        mths_since_last_delinq      10.377155              10.0  -0.377155
# 98        mths_since_last_delinq       6.513331               7.0   0.486669
# 99        mths_since_last_record      35.000407              35.0  -0.000407
# 100       mths_since_last_record      36.392926              36.0  -0.392926
# 101       mths_since_last_record      42.599820              43.0   0.400180
# 102       mths_since_last_record      58.102860              58.0  -0.102860
# 103       mths_since_last_record      24.242453              24.0  -0.242453
# 104       mths_since_last_record      30.079218              30.0  -0.079218

# %%
# desfazendo um dos arredondamentos para que os valores de score fiquem entre o máximo e mínimo selecionados

df_scorecard['score_final'] = df_scorecard['score_preliminar']
df_scorecard['score_final'][33] = 5
df_scorecard
# Out:
#      index                         nome_feature  coeficiente        p_valor  \
# 0        0                            intercept    -1.371397            NaN
# 1        1                              grade:A     1.120239   1.705517e-30
# 2        2                              grade:B     0.891872   1.198637e-42
# 3        3                              grade:C     0.706093   1.383027e-31
# 4        4                              grade:D     0.529578   2.517464e-20
# 5        5                              grade:E     0.344007   1.869595e-11
# 6        6                              grade:F     0.181411   6.870495e-04
# 7        7                   home_ownership:OWN     0.080838   1.659498e-04
# 8        8              home_ownership:MORTGAGE     0.118092   3.618968e-18
# 9        9                     addr_state:NM_VA     0.038921   2.552631e-01
# 10      10                        addr_state:NY     0.061426   1.807077e-02
# 11      11         addr_state:OK_TN_MO_LA_MD_NC     0.055567   2.495962e-02
# 12      12                        addr_state:CA     0.066356   3.495677e-03
# 13      13               addr_state:UT_KY_AZ_NJ     0.075903   4.320970e-03
# 14      14            addr_state:AR_MI_PA_OH_MN     0.140124   6.295668e-09
# 15      15            addr_state:RI_MA_DE_SD_IN     0.091620   4.048894e-03
# 16      16                  addr_state:GA_WA_OR     0.209991   2.350712e-13
# 17      17                     addr_state:WI_MT     0.263169   2.998592e-07
# 18      18                        addr_state:TX     0.213835   1.349446e-14
# 19      19                     addr_state:IL_CT     0.275203   1.639024e-18
# 20      20         addr_state:KS_SC_CO_VT_AK_MS     0.302989   3.206527e-20
# 21      21         addr_state:WV_NH_WY_DC_ME_ID     0.448291   5.728476e-16
# 22      22     verification_status:Not Verified     0.108887   4.650683e-12
# 23      23  verification_status:Source Verified     0.005561   6.987679e-01
# 24      24                  purpose:credit_card     0.302932   2.090231e-23
# 25      25           purpose:debt_consolidation     0.189525   1.130595e-11
# 26      26           purpose:oth__med__vacation     0.192464   7.409649e-09
# 27      27  purpose:major_purch__car__home_impr     0.247194   1.573550e-13
# 28      28                initial_list_status:w     0.069243   7.285469e-07
# 29      29                              term:36     0.085792   1.492822e-08
# 30      30                         emp_length:1     0.112939   5.022189e-05
# 31      31                       emp_length:2-4     0.126190   4.443237e-10
# 32      32                       emp_length:5-6     0.076540   8.095626e-04
# 33      33                       emp_length:7-9     0.058436   8.725434e-03
# 34      34                        emp_length:10     0.129819   5.004927e-11
# 35      35               mths_since_issue_d:<38     1.040987  4.818019e-142
# 36      36             mths_since_issue_d:38-39     0.874636  5.561227e-123
# 37      37             mths_since_issue_d:40-41     0.776557  9.703474e-102
# 38      38             mths_since_issue_d:42-48     0.556012   3.875045e-67
# 39      39             mths_since_issue_d:49-52     0.419556   1.706727e-34
# 40      40             mths_since_issue_d:53-64     0.184479   1.091953e-08
# 41      41             mths_since_issue_d:65-84    -0.071832   2.221073e-02
# 42      42                      int_rate:<9.548     0.909501   1.862597e-28
# 43      43                int_rate:9.548-12.025     0.577437   2.684331e-33
# 44      44                int_rate:12.025-15.74     0.305270   1.004183e-14
# 45      45                int_rate:15.74-20.281     0.096453   1.894529e-03
# 46      46  mths_since_earliest_cr_line:141-164     0.076505   4.289903e-03
# 47      47  mths_since_earliest_cr_line:165-247     0.047317   2.945645e-02
# 48      48  mths_since_earliest_cr_line:248-270     0.074403   8.673981e-03
# 49      49  mths_since_earliest_cr_line:271-352     0.136221   9.650868e-08
# 50      50     mths_since_earliest_cr_line:>352     0.133434   3.864068e-06
# 51      51                        delinq_2yrs:0     0.064171   2.913999e-01
# 52      52                      delinq_2yrs:1-3     0.008231   8.854481e-01
# 53      53                     inq_last_6mths:0     0.729960   3.825313e-09
# 54      54                   inq_last_6mths:1-2     0.587147   2.077073e-06
# 55      55                   inq_last_6mths:3-6     0.386399   1.872395e-03
# 56      56                         open_acc:1-3    -0.064582   7.185561e-01
# 57      57                        open_acc:4-12    -0.126531   4.704781e-01
# 58      58                       open_acc:13-17    -0.137366   4.342373e-01
# 59      59                       open_acc:18-22    -0.159259   3.673023e-01
# 60      60                       open_acc:23-25    -0.136569   4.527126e-01
# 61      61                       open_acc:26-30    -0.150296   4.212804e-01
# 62      62                        open_acc:>=31    -0.186017   3.564643e-01
# 63      63                          pub_rec:3-4     0.033668   7.305199e-01
# 64      64                          pub_rec:>=5     0.040164   8.330900e-01
# 65      65                      total_acc:28-51    -0.018672   2.191139e-01
# 66      66                       total_acc:>=52    -0.034813   4.048570e-01
# 67      67                   acc_now_delinq:>=1     0.168730   1.327620e-01
# 68      68              total_rev_hi_lim:5K-10K     0.013172   6.176985e-01
# 69      69             total_rev_hi_lim:10K-20K    -0.000652   9.796862e-01
# 70      70             total_rev_hi_lim:20K-30K     0.005408   8.477255e-01
# 71      71             total_rev_hi_lim:30K-40K    -0.011052   7.258825e-01
# 72      72             total_rev_hi_lim:40K-55K     0.041321   2.307736e-01
# 73      73             total_rev_hi_lim:55K-95K     0.063422   9.999395e-02
# 74      74                total_rev_hi_lim:>95K     0.202200   7.614600e-04
# 75      75                   annual_inc:20K-30K    -0.063282   1.685759e-01
# 76      76                   annual_inc:30K-40K    -0.007194   8.712086e-01
# 77      77                   annual_inc:40K-50K     0.107380   1.572607e-02
# 78      78                   annual_inc:50K-60K     0.151162   7.886802e-04
# 79      79                   annual_inc:60K-70K     0.237277   2.708393e-07
# 80      80                   annual_inc:70K-80K     0.298050   2.431056e-10
# 81      81                   annual_inc:80K-90K     0.384270   4.726272e-15
# 82      82                  annual_inc:90K-100K     0.398392   3.878425e-15
# 83      83                 annual_inc:100K-120K     0.454093   1.786500e-19
# 84      84                 annual_inc:120K-140K     0.545912   8.986038e-22
# 85      85                     annual_inc:>140K     0.469262   6.838232e-19
# 86      86                            dti:<=1.4     0.247248   1.002660e-02
# 87      87                          dti:1.4-3.5     0.349212   1.678895e-05
# 88      88                          dti:3.5-7.7     0.309396   1.191862e-05
# 89      89                         dti:7.7-10.5     0.261016   1.964027e-04
# 90      90                        dti:10.5-16.1     0.186179   6.195766e-03
# 91      91                        dti:16.1-20.3     0.097779   1.503448e-01
# 92      92                        dti:20.3-21.7     0.093219   1.865510e-01
# 93      93                        dti:21.7-22.4     0.040482   5.872295e-01
# 94      94                          dti:22.4-35    -0.001991   9.763588e-01
# 95      95       mths_since_last_delinq:Missing     0.043164   4.867386e-01
# 96      96          mths_since_last_delinq:4-30     0.106192   6.470523e-02
# 97      97         mths_since_last_delinq:31-56     0.110025   8.165944e-02
# 98      98          mths_since_last_delinq:>=57     0.069058   2.835101e-01
# 99      99       mths_since_last_record:Missing     0.371095   5.331083e-05
# 100    100          mths_since_last_record:3-20     0.385860   3.406373e-03
# 101    101         mths_since_last_record:21-31     0.451669   3.166182e-04
# 102    102         mths_since_last_record:32-80     0.616042   1.622830e-10
# 103    103         mths_since_last_record:81-86     0.257033   2.331781e-02
# 104    104           mths_since_last_record:>86     0.318918   7.666102e-04
#
#            nome_original_feature  calculo_score  score_preliminar  diferenca  \
# 0                      intercept     169.679612             170.0   0.320388
# 1                          grade     105.657014             106.0   0.342986
# 2                          grade      84.118238              84.0  -0.118238
# 3                          grade      66.596188              67.0   0.403812
# 4                          grade      49.947893              50.0   0.052107
# 5                          grade      32.445523              32.0  -0.445523
# 6                          grade      17.110003              17.0  -0.110003
# 7                 home_ownership       7.624322               8.0   0.375678
# 8                 home_ownership      11.138061              11.0  -0.138061
# 9                     addr_state       3.670930               4.0   0.329070
# 10                    addr_state       5.793474               6.0   0.206526
# 11                    addr_state       5.240905               5.0  -0.240905
# 12                    addr_state       6.258459               6.0  -0.258459
# 13                    addr_state       7.158925               7.0  -0.158925
# 14                    addr_state      13.216036              13.0  -0.216036
# 15                    addr_state       8.641286               9.0   0.358714
# 16                    addr_state      19.805597              20.0   0.194403
# 17                    addr_state      24.821140              25.0   0.178860
# 18                    addr_state      20.168155              20.0  -0.168155
# 19                    addr_state      25.956142              26.0   0.043858
# 20                    addr_state      28.576881              29.0   0.423119
# 21                    addr_state      42.281261              42.0  -0.281261
# 22           verification_status      10.269874              10.0  -0.269874
# 23           verification_status       0.524488               1.0   0.475512
# 24                       purpose      28.571450              29.0   0.428550
# 25                       purpose      17.875283              18.0   0.124717
# 26                       purpose      18.152540              18.0  -0.152540
# 27                       purpose      23.314443              23.0  -0.314443
# 28           initial_list_status       6.530746               7.0   0.469254
# 29                          term       8.091595               8.0  -0.091595
# 30                    emp_length      10.652024              11.0   0.347976
# 31                    emp_length      11.901815              12.0   0.098185
# 32                    emp_length       7.218996               7.0  -0.218996
# 33                    emp_length       5.511493               6.0   0.488507
# 34                    emp_length      12.244097              12.0  -0.244097
# 35            mths_since_issue_d      98.182189              98.0  -0.182189
# 36            mths_since_issue_d      82.492537              82.0  -0.492537
# 37            mths_since_issue_d      73.242102              73.0  -0.242102
# 38            mths_since_issue_d      52.441044              52.0  -0.441044
# 39            mths_since_issue_d      39.571061              40.0   0.428939
# 40            mths_since_issue_d      17.399386              17.0  -0.399386
# 41            mths_since_issue_d      -6.774941              -7.0  -0.225059
# 42                      int_rate      85.780919              86.0   0.219081
# 43                      int_rate      54.461777              54.0  -0.461777
# 44                      int_rate      28.792007              29.0   0.207993
# 45                      int_rate       9.097142               9.0  -0.097142
# 46   mths_since_earliest_cr_line       7.215698               7.0  -0.215698
# 47   mths_since_earliest_cr_line       4.462802               4.0  -0.462802
# 48   mths_since_earliest_cr_line       7.017404               7.0  -0.017404
# 49   mths_since_earliest_cr_line      12.847902              13.0   0.152098
# 50   mths_since_earliest_cr_line      12.585068              13.0   0.414932
# 51                   delinq_2yrs       6.052356               6.0  -0.052356
# 52                   delinq_2yrs       0.776341               1.0   0.223659
# 53                inq_last_6mths      68.847242              69.0   0.152758
# 54                inq_last_6mths      55.377585              55.0  -0.377585
# 55                inq_last_6mths      36.443771              36.0  -0.443771
# 56                      open_acc      -6.091103              -6.0   0.091103
# 57                      open_acc     -11.933968             -12.0  -0.066032
# 58                      open_acc     -12.955884             -13.0  -0.044116
# 59                      open_acc     -15.020730             -15.0   0.020730
# 60                      open_acc     -12.880750             -13.0  -0.119250
# 61                      open_acc     -14.175343             -14.0   0.175343
# 62                      open_acc     -17.544497             -18.0  -0.455503
# 63                       pub_rec       3.175462               3.0  -0.175462
# 64                       pub_rec       3.788093               4.0   0.211907
# 65                     total_acc      -1.761048              -2.0  -0.238952
# 66                     total_acc      -3.283412              -3.0   0.283412
# 67                acc_now_delinq      15.914052              16.0   0.085948
# 68              total_rev_hi_lim       1.242291               1.0  -0.242291
# 69              total_rev_hi_lim      -0.061540              -0.0   0.061540
# 70              total_rev_hi_lim       0.510099               1.0   0.489901
# 71              total_rev_hi_lim      -1.042381              -1.0   0.042381
# 72              total_rev_hi_lim       3.897255               4.0   0.102745
# 73              total_rev_hi_lim       5.981773               6.0   0.018227
# 74              total_rev_hi_lim      19.070802              19.0  -0.070802
# 75                    annual_inc      -5.968510              -6.0  -0.031490
# 76                    annual_inc      -0.678552              -1.0  -0.321448
# 77                    annual_inc      10.127727              10.0  -0.127727
# 78                    annual_inc      14.257036              14.0  -0.257036
# 79                    annual_inc      22.379132              22.0  -0.379132
# 80                    annual_inc      28.110986              28.0  -0.110986
# 81                    annual_inc      36.242975              36.0  -0.242975
# 82                    annual_inc      37.574917              38.0   0.425083
# 83                    annual_inc      42.828406              43.0   0.171594
# 84                    annual_inc      51.488462              51.0  -0.488462
# 85                    annual_inc      44.259128              44.0  -0.259128
# 86                           dti      23.319593              23.0  -0.319593
# 87                           dti      32.936407              33.0   0.063593
# 88                           dti      29.181160              29.0  -0.181160
# 89                           dti      24.618096              25.0   0.381904
# 90                           dti      17.559791              18.0   0.440209
# 91                           dti       9.222165               9.0  -0.222165
# 92                           dti       8.792124               9.0   0.207876
# 93                           dti       3.818097               4.0   0.181903
# 94                           dti      -0.187784              -0.0   0.187784
# 95        mths_since_last_delinq       4.071030               4.0  -0.071030
# 96        mths_since_last_delinq      10.015689              10.0  -0.015689
# 97        mths_since_last_delinq      10.377155              10.0  -0.377155
# 98        mths_since_last_delinq       6.513331               7.0   0.486669
# 99        mths_since_last_record      35.000407              35.0  -0.000407
# 100       mths_since_last_record      36.392926              36.0  -0.392926
# 101       mths_since_last_record      42.599820              43.0   0.400180
# 102       mths_since_last_record      58.102860              58.0  -0.102860
# 103       mths_since_last_record      24.242453              24.0  -0.242453
# 104       mths_since_last_record      30.079218              30.0  -0.079218
#
#      score_final
# 0          170.0
# 1          106.0
# 2           84.0
# 3           67.0
# 4           50.0
# 5           32.0
# 6           17.0
# 7            8.0
# 8           11.0
# 9            4.0
# 10           6.0
# 11           5.0
# 12           6.0
# 13           7.0
# 14          13.0
# 15           9.0
# 16          20.0
# 17          25.0
# 18          20.0
# 19          26.0
# 20          29.0
# 21          42.0
# 22          10.0
# 23           1.0
# 24          29.0
# 25          18.0
# 26          18.0
# 27          23.0
# 28           7.0
# 29           8.0
# 30          11.0
# 31          12.0
# 32           7.0
# 33           5.0
# 34          12.0
# 35          98.0
# 36          82.0
# 37          73.0
# 38          52.0
# 39          40.0
# 40          17.0
# 41          -7.0
# 42          86.0
# 43          54.0
# 44          29.0
# 45           9.0
# 46           7.0
# 47           4.0
# 48           7.0
# 49          13.0
# 50          13.0
# 51           6.0
# 52           1.0
# 53          69.0
# 54          55.0
# 55          36.0
# 56          -6.0
# 57         -12.0
# 58         -13.0
# 59         -15.0
# 60         -13.0
# 61         -14.0
# 62         -18.0
# 63           3.0
# 64           4.0
# 65          -2.0
# 66          -3.0
# 67          16.0
# 68           1.0
# 69          -0.0
# 70           1.0
# 71          -1.0
# 72           4.0
# 73           6.0
# 74          19.0
# 75          -6.0
# 76          -1.0
# 77          10.0
# 78          14.0
# 79          22.0
# 80          28.0
# 81          36.0
# 82          38.0
# 83          43.0
# 84          51.0
# 85          44.0
# 86          23.0
# 87          33.0
# 88          29.0
# 89          25.0
# 90          18.0
# 91           9.0
# 92           9.0
# 93           4.0
# 94          -0.0
# 95           4.0
# 96          10.0
# 97          10.0
# 98           7.0
# 99          35.0
# 100         36.0
# 101         43.0
# 102         58.0
# 103         24.0
# 104         30.0

# %% [markdown]
# Agora o scorecard está correto dentro dos valores escolhidos.

# %%
min_sum_score_prel = df_scorecard.groupby('nome_original_feature')['score_final'].min().sum()
min_sum_score_prel
# Out:
# 300.0

# %%
max_sum_score_prel = df_scorecard.groupby('nome_original_feature')['score_final'].max().sum()
max_sum_score_prel
# Out:
# 850.0

# %% [markdown]
# ### 1.1 Calculando score de crédito
#
# Aqui foi calculado o score de cada registro do dataset de teste criado abaixo.

# %%
# criando um dataframe com os dados de teste

df_features = pd.DataFrame(columns = nomes_features, data = X_test)


# inserindo nova coluna no dataset

df_features.insert(0, 'intercept', 1)

# %%
scorecard_scores = df_scorecard['score_final']

# %%
df_features.shape
# Out:
# (139886, 105)

# %%
scorecard_scores.shape
# Out:
# (105,)

# %%
scorecard_scores = scorecard_scores.values.reshape(105, 1)

# %%
# multiplicando os valores de teste com score para obter o score de cada registro 

y_scores = df_features.dot(scorecard_scores)

# %%
y_scores
# Out:
#             0
# 0       404.0
# 1       458.0
# 2       418.0
# 3       571.0
# 4       548.0
# ...       ...
# 139881  558.0
# 139882  568.0
# 139883  618.0
# 139884  604.0
# 139885  566.0
#
# [139886 rows x 1 columns]

# %%
y_scores.min()
# Out:
# 0    237.0
# dtype: float64

# %% [markdown]
# ### 1.2 Calculando a probabilidade de inadimplência

# %%
# divide-se a diferença entre as pontuações e a pontuação mínima pela
# diferença entre a pontuação máxima e a pontuação mínima
# multiplica-se pela diferença entre a soma máxima dos coeficientes e a soma mínima dos coeficientes
# adiciona-se a soma mínima dos coeficientes

sum_coef_score = ((y_scores - min_score) / (max_score - min_score)) * (max_sum_coef - min_sum_coef) + min_sum_coef

# %%
y_proba_score = np.exp(sum_coef_score) / (np.exp(sum_coef_score) + 1)

y_proba_score.head()
# Out:
#           0
# 0  0.752690
# 1  0.843638
# 2  0.779275
# 3  0.947032
# 4  0.933379

# %% [markdown]
# ### 1.3 Definindo pontos de corte
#
# Agora as métricas calculadas serão utilizadas para estipular um ponto de corte e que ajude a decidir se um empréstimo será concedido ou não.

# %%
modelo_pi = joblib.load('modelos/modelo_pi.sav')

# %%
y_pred_proba = modelo_pi.model.predict_proba(X_test)[:, 1]

taxa_falso_pos, taxa_verdadeiro_pos, thresholds = roc_curve(y_test, y_pred_proba)

# %%
# concatena-se as três colunas

df_cutoffs = pd.concat([pd.DataFrame(thresholds), pd.DataFrame(taxa_falso_pos), pd.DataFrame(taxa_verdadeiro_pos)], axis = 1)

df_cutoffs.columns = ['thresholds', 'taxa_falso_pos', 'taxa_verdadeiro_pos']

df_cutoffs.head()
# Out:
#    thresholds  taxa_falso_pos  taxa_verdadeiro_pos
# 0    1.992458        0.000000             0.000000
# 1    0.992458        0.000000             0.000008
# 2    0.989886        0.000000             0.000393
# 3    0.989883        0.000065             0.000393
# 4    0.989648        0.000065             0.000506

# %%
df_cutoffs['thresholds'][0] = 1 - 1 / np.power(10, 16)


# calculando score correspondente de cada thresholds

df_cutoffs['score'] = ((np.log(df_cutoffs['thresholds'] / (1 - df_cutoffs['thresholds'])) - min_sum_coef) * ((max_score - min_score) / (max_sum_coef - min_sum_coef)) + min_score).round()
df_cutoffs['score'][0] = max_score
df_cutoffs.head()
# Out:
#    thresholds  taxa_falso_pos  taxa_verdadeiro_pos  score
# 0    1.000000        0.000000             0.000000  850.0
# 1    0.992458        0.000000             0.000008  759.0
# 2    0.989886        0.000000             0.000393  731.0
# 3    0.989883        0.000065             0.000393  731.0
# 4    0.989648        0.000065             0.000506  729.0

# %%
def n_aprovado(p):
    return np.where(y_pred_proba >= p, 1, 0).sum()

# %%
df_cutoffs['n_aprovado']     = df_cutoffs['thresholds'].apply(n_aprovado)
df_cutoffs['n_rejeitado']    = y_pred_proba.shape[0] - df_cutoffs['n_aprovado']
df_cutoffs['taxa_aprovacao'] = df_cutoffs['n_aprovado'] / y_pred_proba.shape[0]
df_cutoffs['taxa_rejeicao']  = 1 - df_cutoffs['taxa_aprovacao']

# %%
df_cutoffs.head()
# Out:
#    thresholds  taxa_falso_pos  taxa_verdadeiro_pos  score  n_aprovado  \
# 0    1.000000        0.000000             0.000000  850.0           0
# 731       123298        0.118582       0.881418
# 732       123282        0.118697       0.881303
# 733       123281        0.118704       0.881296
# 734       123261        0.118847       0.881153
# 735       123260        0.118854       0.881146
# 736       123166        0.119526       0.880474
# 737       123165        0.119533       0.880467
# 738       123107        0.119948       0.880052
# 739       123105        0.119962       0.880038
# 740       123104        0.119969       0.880031
# 741       123103        0.119976       0.880024
# 742       123076        0.120169       0.879831
# 743       123075        0.120176       0.879824
# 744       123071        0.120205       0.879795
# 745       123070        0.120212       0.879788
# 746       123058        0.120298       0.879702
# 747       123057        0.120305       0.879695
# 748       123054        0.120327       0.879673
# 749       123053        0.120334       0.879666
# 750       123045        0.120391       0.879609
# 751       123044        0.120398       0.879602
# 752       122988        0.120798       0.879202
# 753       122987        0.120806       0.879194
# 754       122973        0.120906       0.879094
# 755       122972        0.120913       0.879087
# 756       122944        0.121113       0.878887
# 757       122943        0.121120       0.878880
# 758       122928        0.121227       0.878773
# 759       122927        0.121234       0.878766
# 760       122923        0.121263       0.878737
# 761       122922        0.121270       0.878730
# 762       122911        0.121349       0.878651
# 763       122910        0.121356       0.878644
# 764       122851        0.121778       0.878222
# 765       122850        0.121785       0.878215
# 766       122823        0.121978       0.878022
# 767       122822        0.121985       0.878015
# 768       122774        0.122328       0.877672
# 769       122773        0.122335       0.877665
# 770       122719        0.122721       0.877279
# 771       122718        0.122729       0.877271
# 772       122708        0.122800       0.877200
# 773       122707        0.122807       0.877193
# 774       122646        0.123243       0.876757
# 775       122645        0.123250       0.876750
# 776       122614        0.123472       0.876528
# 777       122612        0.123486       0.876514
# 778       122586        0.123672       0.876328
# 779       122585        0.123679       0.876321
# 780       122533        0.124051       0.875949
# 781       122532        0.124058       0.875942
# 782       122528        0.124087       0.875913
# 783       122527        0.124094       0.875906
# 784       122501        0.124280       0.875720
# 785       122500        0.124287       0.875713
# 786       122437        0.124737       0.875263
# 787       122436        0.124744       0.875256
# 788       122383        0.125123       0.874877
# 789       122382        0.125130       0.874870
# 790       122288        0.125802       0.874198
# 791       122287        0.125810       0.874190
# 792       122218        0.126303       0.873697
# 793       122217        0.126310       0.873690
# 794       122214        0.126331       0.873669
# 795       122212        0.126346       0.873654
# 796       122176        0.126603       0.873397
# 797       122175        0.126610       0.873390
# 798       122170        0.126646       0.873354
# 799       122169        0.126653       0.873347
# 800       122153        0.126768       0.873232
# 801       122152        0.126775       0.873225
# 802       122134        0.126903       0.873097
# 803       122133        0.126910       0.873090
# 804       122028        0.127661       0.872339
# 805       122027        0.127668       0.872332
# 806       122008        0.127804       0.872196
# 807       122006        0.127818       0.872182
# 808       121979        0.128011       0.871989
# 809       121978        0.128019       0.871981
# 810       121968        0.128090       0.871910
# 811       121967        0.128097       0.871903
# 812       121933        0.128340       0.871660
# 813       121932        0.128347       0.871653
# 814       121922        0.128419       0.871581
# 815       121921        0.128426       0.871574
# 816       121869        0.128798       0.871202
# 817       121868        0.128805       0.871195
# 818       121843        0.128984       0.871016
# 819       121842        0.128991       0.871009
# 820       121831        0.129069       0.870931
# 821       121830        0.129077       0.870923
# 822       121741        0.129713       0.870287
# 823       121740        0.129720       0.870280
# 824       121738        0.129734       0.870266
# 825       121737        0.129741       0.870259
# 826       121729        0.129799       0.870201
# 827       121728        0.129806       0.870194
# 828       121706        0.129963       0.870037
# 829       121705        0.129970       0.870030
# 830       121689        0.130084       0.869916
# 831       121688        0.130092       0.869908
# 832       121622        0.130563       0.869437
# 833       121621        0.130571       0.869429
# 834       121617        0.130599       0.869401
# 835       121616        0.130606       0.869394
# 836       121614        0.130621       0.869379
# 837       121613        0.130628       0.869372
# 838       121612        0.130635       0.869365
# 839       121611        0.130642       0.869358
# 840       121594        0.130764       0.869236
# 841       121593        0.130771       0.869229
# 842       121580        0.130864       0.869136
# 843       121578        0.130878       0.869122
# 844       121551        0.131071       0.868929
# 845       121550        0.131078       0.868922
# 846       121525        0.131257       0.868743
# 847       121524        0.131264       0.868736
# 848       121506        0.131393       0.868607
# 849       121505        0.131400       0.868600
# 850       121453        0.131772       0.868228
# 851       121452        0.131779       0.868221
# 852       121426        0.131965       0.868035
# 853       121425        0.131972       0.868028
# 854       121411        0.132072       0.867928
# 855       121410        0.132079       0.867921
# 856       121401        0.132143       0.867857
# 857       121400        0.132150       0.867850
# 858       121354        0.132479       0.867521
# 859       121353        0.132486       0.867514
# 860       121339        0.132587       0.867413
# 861       121338        0.132594       0.867406
# 862       121296        0.132894       0.867106
# 863       121295        0.132901       0.867099
# 864       121292        0.132923       0.867077
# 865       121291        0.132930       0.867070
# 866       121268        0.133094       0.866906
# 867       121267        0.133101       0.866899
# 868       121256        0.133180       0.866820
# 869       121255        0.133187       0.866813
# 870       121202        0.133566       0.866434
# 871       121201        0.133573       0.866427
# 872       121198        0.133594       0.866406
# 873       121197        0.133602       0.866398
# 874       121154        0.133909       0.866091
# 875       121153        0.133916       0.866084
# 876       121145        0.133973       0.866027
# 877       121144        0.133981       0.866019
# 878       121103        0.134274       0.865726
# 879       121102        0.134281       0.865719
# 880       121082        0.134424       0.865576
# 881       121081        0.134431       0.865569
# 882       121073        0.134488       0.865512
# 883       121072        0.134495       0.865505
# 884       121070        0.134510       0.865490
# 885       121069        0.134517       0.865483
# 886       121063        0.134560       0.865440
# 887       121062        0.134567       0.865433
# 888       121032        0.134781       0.865219
# 889       121031        0.134788       0.865212
# 890       121018        0.134881       0.865119
# 891       121017        0.134888       0.865112
# 892       120995        0.135046       0.864954
# 893       120994        0.135053       0.864947
# 894       120950        0.135367       0.864633
# 895       120949        0.135375       0.864625
# 896       120915        0.135618       0.864382
# 897       120913        0.135632       0.864368
# 898       120857        0.136032       0.863968
# 899       120855        0.136046       0.863954

# %%
# salvando dados

df_scorecard.to_csv('dados/dados_scorecard.csv', index = False)

dados_treino1 = pd.DataFrame(columns = nomes_features, data = X_train)
dados_treino2 = pd.DataFrame(columns = ['target'], data = y_train)
dados_treino  = pd.concat([dados_treino1, dados_treino2], axis = 1)
dados_treino.to_csv('dados/dados_populacao_de_treino.csv', index = False)

# %% [markdown]
# ---
